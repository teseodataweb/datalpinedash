# %% [markdown]
# # **Limpieza**

# %% [markdown]
# #### LIBRERÍAS

# %%
import pandas as pd # Manipulación df
import os # Directorios
import re # Manipulación de cadenas de texto (expresiones regulares)
import unicodedata # Función para eliminar acentos
from datetime import datetime, date  # Para trabajar con fechas y horas
from currency_converter import CurrencyConverter # convertidor de monedas
from dateutil.relativedelta import relativedelta  # Para calcular diferencias entre fechas, incluyendo años, meses y días

# %% [markdown]
# Estilo de impresiones

# %%
# Colores ANSI
BLACK = "\033[90m"
RED = "\033[91m"
GREEN = "\033[92m"
YELLOW = "\033[93m"
BLUE = "\033[94m"
MAGENTA = "\033[95m"
CYAN = "\033[96m"
WHITE = "\033[97m"
RESET = "\033[0m"  # Restablecer el color por defecto
# Estilos de texto
BOLD = "\033[1m"
UNDERLINE = "\033[4m"
BLINK = "\033[5m"
REVERSE = "\033[7m"  # Invertir colores (fondo y texto)

# %% [markdown]
# #### CARGAR ARCHIVO

# %% [markdown]
# Solo cambia el nombre en 'archivo_filename' y su ruta con 'archivo_dir'

# %%
directorio_actual = os.getcwd() # Directorio actual de trabajo
# Ruta relativa al archivo CSV
archivo_filename = "ruta/relativa/al/archivo.csv"
archivo_dir = os.path.join(directorio_actual)
archivo_path = os.path.join(archivo_dir, archivo_filename)

# %%
directorio_actual = os.getcwd() # Directorio actual de trabajo
# Ruta relativa al archivo CSV
archivo_filename = "C:/Users/yoe11/OneDrive/Escritorio/Base_Puebla_Agosto 2024.csv"
archivo_dir = os.path.join(directorio_actual)
archivo_path = os.path.join(archivo_dir, archivo_filename)

# %% [markdown]
# Elige el tipo de archivo a leer

# %%
#df = pd.read_excel(archivo_path) 
df = pd.read_csv(archivo_path)
df.info()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 #df = pd.read_excel(archivo_path)
# ----> 2 df = pd.read_csv(archivo_path)
#       3 df.info()
#
# File c:\Users\yoe11\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\yoe11\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\yoe11\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\yoe11\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 17 fields in line 312, saw 18

# %% [markdown]
# #### LIMPIEZA NULOS

# %%
df.fillna({'precio': 0}, inplace=True) 
df.fillna({'denominacion': ''}, inplace=True) 
df.fillna({'propiedad': 'Propiedad sin título'}, inplace=True) 
df.fillna({'metros_total': 0}, inplace=True) 
df.fillna({'metros_construido': 0}, inplace=True) 
#df.fillna({'tiempo_de_publicacion': ''}, inplace=True) 
df.fillna({'tipo': 'Propiedad sin tipo de casa'}, inplace=True) 
df.fillna({'estacionamientos': 0}, inplace=True) 
df.fillna({'recamaras': 0}, inplace=True) 
df.fillna({'banos': 0}, inplace=True) 
df.fillna({'medio_banos': 0}, inplace=True) 
df.fillna({'seguridad_privada': 'No'}, inplace=True) 
df.fillna({'ubicacion': 'Propiedad sin ubicación'}, inplace=True) 
df.fillna({'url': '-'}, inplace=True) 
df.fillna({'descripcion': "Propiedad sin descripcion"}, inplace=True)

# %% [markdown]
# # Duplicados
# * Estandarizar descripción
# * Eliminación de los duplicados, dejando uno de los resultantes

# %%
df.columns
# Out:
# Index(['precio', 'denominacion', 'propiedad', 'metros_total',
#        'metros_construido', 'tiempo_de_publicacion', 'tipo',
#        'estacionamientos', 'recamaras', 'banos', 'medio_banos',
#        'seguridad_privada', 'lugar', 'Colonia', 'CP', 'ubicacion', 'url',
#        'descripcion'],
#       dtype='object')

# %%
# Convierte todos los valores a strings, maneja NaN o None como cadenas vacías
df['descripcion'] = df['descripcion'].astype(str)
# Convertir a minúsculas
df['descripcion'] = df['descripcion'].str.lower()
# Eliminar acentos y carácteres especiales
import unicodedata 
def eliminar_acentos(texto):
    texto_normalizado = unicodedata.normalize('NFKD', texto)
    return ''.join(char for char in texto_normalizado if unicodedata.category(char) != 'Mn')
df['descripcion'] = df['descripcion'].apply(eliminar_acentos)
df['descripcion'] = df['descripcion'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)
inicio = df.shape

# %% [markdown]
# ## a) Con todos los datos iguales

# %%
duplicados = df.loc[df.duplicated()]
shapes = duplicados.shape
print(duplicados)
print(f'{BLUE}Los duplicados encontrados son: {RESET}',f'{RED}{shapes}{RESET}')
# Out:
#         precio denominacion  \
# 24      372608          MXN
# 27      373340          MXN
# 29      373500          MXN
# 33      395100          MXN
# 41      400012          MXN
# ...        ...          ...
# 4440  31674000          MXN
# 4441  31674000          MXN
# 4443  32000000          MXN
# 4445  33000000          MXN
# 4450  35000000          MXN
#
#                                                                                     propiedad  \
# 24    ¡¡EXCELENTE OPORTUNIDAD DE INVERSIÒN!! HERMOSA CASA EN VENTA. EL CERRITO, PUEBLA PUEBLA
# 27                                     CASA EN VENTA EN EL FRACCIONAMIENTO SANTA CLARA PUEBLA
# 29                                                  Casa en venta en San José, Puebla, México
# 33                                                 VENTA DE CASA EN COLONIA LOMA LINDA PUEBLA
# 41                            CASA EN VENTA. ESPAÑA COL GEOVILLAS DEL SUR. PUEBLA, PUEBLA. BM
# ...                                                                                       ...
# 4440               Casa en Preventa en Residencial San Ángel, Reserva Territorial Atlixcáyotl
# 4441               Casa en Preventa en Residencial San Ángel, Reserva Territorial Atlixcáyotl
# 4443                               Casa en Venta con amplio jardín en La Concepción, Zavaleta
# 4445                       Casa en venta en Tepetzintla, Puebla, por Club de Golf las Fuentes
# 4450          CASA EN VENTA FRACC. LA MISIÓN FRENTE A LA VISTA, ZONA ANGELOPOLIS, ATLIXCAYOTL
#
#       metros_total  metros_construido tiempo_de_publicacion  tipo  \
# 24             120                210   2023-10-23 00:00:00  Casa
# 27              70                 60   2023-06-16 00:00:00  Casa
# 29             180                180   2023-06-08 00:00:00  Casa
# 33              90                100   2023-10-17 00:00:00  Casa
# 41              65                 80            02/19/2024  Casa
# ...            ...                ...                   ...   ...
# 4440           416                829   2023-04-24 00:00:00  Casa
# 4441           416                829   2023-04-24 00:00:00  Casa
# 4443          1918                807   2023-04-24 00:00:00  Casa
# 4445          5000                596   2023-03-29 00:00:00  Casa
# 4450          1600                800            02/19/2024  Casa
#
#       estacionamientos  recamaras  banos  medio_banos seguridad_privada  \
# 24                   2          3      1            0                No
# 27                   1          2      1            0                No
# 29                   2          4      1            0                No
# 33                   2          3      1            0                No
# 41                   2          3      1            0                No
# ...                ...        ...    ...          ...               ...
# 4440                 1          5      7            0                No
# 4441                 1          5      7            0                No
# 4443                 1          4      3            0                No
# 4445                 1          2      3            0                No
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   vivienda campestre en puebla muy cerca de la constancia y club de golf las fuentes a un minuto de la calle esteban de antunano  casa principal estilo antiguo con patio al centro capilla y cocina estilo tradicional bodega y taller casa de visitas independiente estanque con jardineras galeron independiente con sala comedor y cocina cuarto de guardado area de cocina exterior casa para el cuidador
# 4450  casa en venta fracc la mision frente a la vista zona angelopolis atlixcayotlprecio 3500000000 casa de un solo nivel superficie de terreno 1600 m2 43 metros lineales de frentesuperficie de construccion 800 m2acabados premium dos cisternas de agua de 12000 litros cada una y un pozo de agua natural amplio estacionamiento techado con porton electrico de 4 cajones amplios depositos y entrada lateral interna a la casa 10 camaras de seguridad y sistemas de alarmas sistemas de hidroneumaticos con suavizador de agua pisos de madera en toda la casa y marmol paneles solares para la energia en la casa se paga 50000 de luz bimensuales 3 calentadores solares de agua incluye todo el servicio de agua caliente en toda la casa solo se utiliza agua caliente de gas en enero y febrero hermoso lobby de entrada intercomunicador por video en la cocina area de tv sala de juegos cuarto principal estudio amplio cuarto de tv con clima medio bano de visita dos habitaciones secundarias con vestidor y bano completo cada una y clima hermoso cuarto principal con amplio vestidor y hermoso bano completo y clima cuarto de oratorio hermoso solarium o jardin interno espectacular jardin trasero de 800 mts cuadrados con amplia terraza amplia sala de juegos y usos multiples con bano completo cuarto de vinos o vinoteca con sotano incluido incluye cava y cocina amplia y hermosa cocina avanti con desayunador y doble refrigerador amplia alacena amplio centro de lavado con patio de tendido o secado natural amplio cuarto de servicio con dos camas individuales y bano completo sistema de sonido sensurround en las areas mas importante de la casaaljor inmobiliariaa6lj
#
# [742 rows x 18 columns]
# Los duplicados encontrados son:  (742, 18)

# %%
df = df.drop_duplicates(keep='first')
shapes = df.shape
print('La base mantuvo una estructura de: ',f'{RED}{shapes}{RESET}')
# Out:
# La base mantuvo una estructura de:  (3712, 18)

# %%
duplicados = df.loc[df.duplicated()]
print(duplicados)
# Out:
# Empty DataFrame
# Columns: [precio, denominacion, propiedad, metros_total, metros_construido, tiempo_de_publicacion, tipo, estacionamientos, recamaras, banos, medio_banos, seguridad_privada, lugar, Colonia, CP, ubicacion, url, descripcion]
# Index: []

# %%
shapes = df.shape
print('La base ha quedado con: ',f'{RED}{shapes}{RESET}', 'de',f'{GREEN}{inicio}{RESET}')
# Out:
# La base ha quedado con:  (3712, 18) de (4454, 18)

# %% [markdown]
# ## b) Descripción y precio iguales

# %%
duplicados = df.loc[df.duplicated(subset=['descripcion','precio'])]
shapes = duplicados.shape
print(duplicados)
print(f'{BLUE}Los duplicados encontrados son: {RESET}',f'{RED}{shapes}{RESET}')
# Out:
#           precio denominacion  \
# 71      442000.0          MXN
# 77      450000.0          MXN
# 142     504000.0          MXN
# 180     519000.0          MXN
# 199     528521.0          MXN
# ...          ...          ...
# 2874   5790000.0          MXN
# 3099   8900000.0          MXN
# 3157   9960000.0          MXN
# 3251  12250000.0          MXN
# 3407  19900000.0          MXN
#
#                                               propiedad  metros_total  \
# 71      VENTA HERMOSA CASA EN PLAZAS AMALUCAN EN PUEBLA           168
# 77          Casa en venta en colonia Cuauhtémoc, Puebla           150
# 142               Casa en venta en Valle del Sol Puebla           180
# 180                 VENTA DE CASA EN PUEBLA DE ZARAGOZA           211
# 199                             VENTA DE CASA EN PUEBLA           224
# ...                                                 ...           ...
# 2874                   Casa en Venta, Colonia La Calera           375
# 3099            Casa en Venta, Colonia La Calera Puebla           512
df = df.drop_duplicates(subset=['descripcion','precio'],keep='first')
shapes = df.shape
print('La base mantuvo una estructura de: ',f'{RED}{shapes}{RESET}')
# Out:
# La base mantuvo una estructura de:  (3398, 15)

# %%
duplicados = df.loc[df.duplicated(subset=['descripcion','precio'])]
print(duplicados)
# Out:
# Empty DataFrame
# Columns: [precio, denominacion, propiedad, metros_total, metros_construido, tiempo_de_publicacion, tipo, estacionamientos, recamaras, banos, medio_banos, seguridad_privada, ubicacion, url, descripcion]
# Index: []

# %% [markdown]
# ## c) M2 construcción, Ubicación y Precio

# %%
duplicados = df.loc[df.duplicated(subset=['metros_construido','ubicacion','precio'])]
shapes = duplicados.shape
print(duplicados)
print(f'{BLUE}Los duplicados encontrados son: {RESET}',f'{RED}{shapes}{RESET}')
# Out:
#           precio denominacion  \
# 14      356000.0          MXN
# 15      356000.0          MXN
# 27      372608.0          MXN
# 33      382900.0          MXN
# 43      400000.0          MXN
# ...          ...          ...
# 3374  17000000.0          MXN
# 3384  17900000.0          MXN
# 3425  22000000.0          MXN
# 3430  24800000.0          MXN
# 3466  38000000.0          MXN
#
#                                               propiedad  metros_total  \
# 14                              CASA EN VENTA EN PUEBLA            80
# 15                 EXCELENTE CASA OPORTUNIDAD INVERSION            70
# 27    ¡¡EXCELENTE OPORTUNIDAD DE INVERSIÒN!! HERMOSA...           120
# 33                      VENTA DE HERMOSA CASA EN PUEBLA           150
# 43                              VENTA DE CASA EN PUEBLA           150
# ...                                                 ...           ...
# 3374  CASA EN VENTA FRACC. CAMPESTRE DEL BOSQUE, EST...           700
# 3384  Residencia Exclusiva en Venta Col. Huexotitla,...           980
# 3425  Casa en Venta con vista al Green en  CLUB DE G...           700
# 3430        Casa En Venta En Fraccionamiento Las Animas          1800
# 3466                  Venta Casa en el Centro Histórico           615
#
#       metros_construido tiempo_de_publicacion  tipo  estacionamientos  \
# 14                   80   2024-07-11 00:00:00  Casa                 2
# 15                   80   2024-07-05 00:00:00  Casa                 2
# 27                  210   2023-09-29 00:00:00  Casa                 2
# 33                  150   2024-05-08 00:00:00  Casa                 2
# 43                  200   2024-04-11 00:00:00  Casa                 2
# ...                 ...                   ...   ...               ...
# 3374                474   2024-07-17 00:00:00  Casa                 5
# 3384                587   2024-07-08 00:00:00  Casa                 7
# 3425                800   2023-04-24 00:00:00  Casa                 7
# 3430               1000   2024-05-28 00:00:00  Casa                 7
# 3466               1106   2024-07-04 00:00:00  Casa                 4
#
#       recamaras  banos  medio_banos seguridad_privada  \
# 14            3      1            1                No
# 15            3      1            1                No
# 27            3      2            1                No
# 33            3      2            0                No
# 43            3      1            1                No
# ...         ...    ...          ...               ...
# 3374          3      4            1                No
# 3384          6      2            0                No
# 3425          4      4            0                No
# 3430          3      6            1                No
# 3466         17      4            0                No
#
#                                    ubicacion  \
# 14             Santa Bárbara, Puebla, Puebla
# 15                    Puebla, Puebla, Puebla
# 27                El Cerrito, Puebla, Puebla
# 33          Héroes de Puebla, Puebla, Puebla
# 43    Jardines de San Manuel, Puebla, Puebla
# ...                                      ...
# 3374    Campestre Del Bosque, Puebla, Puebla
# 3384                 Alpha 2, Puebla, Puebla
# 3425             Las Fuentes, Puebla, Puebla
# 3430              Las Animas, Puebla, Puebla
# 3466        Centro Histórico, Puebla, Puebla
#
#                                                     url  \
# 14    https://www.lamudi.com.mx/detalle/41032-73-599...
# 15    https://www.lamudi.com.mx/detalle/41032-73-351...
# 27    https://www.lamudi.com.mx/detalle/41032-73-db4...
# 33    https://www.lamudi.com.mx/detalle/41032-73-e71...
# 43    https://www.lamudi.com.mx/detalle/41032-73-922...
# ...                                                 ...
# 3374  https://www.lamudi.com.mx/detalle/41032-73-aed...
# 3384  https://www.lamudi.com.mx/detalle/41032-73-11b...
# 3425  https://www.lamudi.com.mx/detalle/41032-73-35f...
# 3430  https://www.lamudi.com.mx/detalle/41032-73-fd3...
# 3466  https://www.lamudi.com.mx/detalle/41032-73-947...
#
#                                             descripcion
# 14    casa en venta en pueblainmueble de recuperacio...
# 15    venta de casa en fraccionamientoexcelente opor...
# 27    elegante casa de 210m2 con una excelente ubica...
# 33    casa en excelente zona con todos los servicios...
# 43    oportunidad unica propiedad de recuperacion ba...
# ...                                                 ...
# 3374  casa en venta fracc campestre del bosque esteb...
# 3384  exclusiva casa en huexotitla puebla residencia...
# 3425  casa en venta en exclusivo residencial club de...
# 3430  zona92 inmobiliaria tiene para ti casa en vent...
# 3466  remax icon te presenta una oportunidad unica d...
#
# [440 rows x 15 columns]
# Los duplicados encontrados son:  (440, 15)

# %%
df = df.drop_duplicates(subset=['metros_construido','ubicacion','precio'],keep='first')
shapes = df.shape
print('La base mantuvo una estructura de: ',f'{RED}{shapes}{RESET}')
# Out:
# La base mantuvo una estructura de:  (2958, 15)

# %%
duplicados = df.loc[df.duplicated(subset=['metros_construido','ubicacion','precio'])]
print(duplicados)
# Out:
# Empty DataFrame
# Columns: [precio, denominacion, propiedad, metros_total, metros_construido, tiempo_de_publicacion, tipo, estacionamientos, recamaras, banos, medio_banos, seguridad_privada, ubicacion, url, descripcion]
# Index: []

# %% [markdown]
# ## d) Características y Precio

# %%
duplicados = df.loc[df.duplicated(subset=['estacionamientos','recamaras','banos','medio_banos','precio'])]
shapes = duplicados.shape
print(duplicados)
print(f'{BLUE}Los duplicados encontrados son: {RESET}',f'{RED}{shapes}{RESET}')
# Out:
#           precio denominacion  \
# 6       325000.0          MXN
# 13      356000.0          MXN
# 16      356000.0          MXN
# 31      382000.0          MXN
# 35      383251.0          MXN
# ...          ...          ...
# 3373  17000000.0          MXN
# 3413  20000000.0          MXN
# 3419  21000000.0          MXN
# 3433  25000000.0          MXN
# 3434  25000000.0          MXN
#
#                                               propiedad  metros_total  \
# 6                    BELLISIMA CASA EN MAYORAZGO PUEBLA            85
# 13                               VENTA DE CASA EN PUBLA            80
# 16    BONITA CASA EN VENTA EN RESIDENCIAL SANTA CLAR...            80
# 31           HERMOSA CASA EN HEROES DE PUEBLA EN PUEBLA           150
# 3419  casa en venta con alberca en zavaleta con vigi...
# 3433  venta casa con alberca la cima puebla zona ang...
# 3434  casa en venta en el mirador la calera pueblacu...
#
# [506 rows x 15 columns]
# Los duplicados encontrados son:  (506, 15)

# %%
df = df.drop_duplicates(subset=['estacionamientos','recamaras','banos','medio_banos','precio'],keep='first')
shapes = df.shape
print('La base mantuvo una estructura de: ',f'{RED}{shapes}{RESET}')
# Out:
# La base mantuvo una estructura de:  (2452, 15)

# %%
duplicados = df.loc[df.duplicated(subset=['estacionamientos','recamaras','banos','medio_banos','precio'])]
print(duplicados)
# Out:
# Empty DataFrame
# Columns: [precio, denominacion, propiedad, metros_total, metros_construido, tiempo_de_publicacion, tipo, estacionamientos, recamaras, banos, medio_banos, seguridad_privada, ubicacion, url, descripcion]
# Index: []

# %%
shapes = df.shape
print('La base ha quedado con: ',f'{RED}{shapes}{RESET}', 'de',f'{GREEN}{inicio}{RESET}')
# Out:
# La base ha quedado con:  (2452, 15) de (3477, 15)

# %% [markdown]
# # 1. Manipulación de precios

# %% [markdown]
# ## a) Precio en descripción

# %% [markdown]
# Agrega las diferentes formas de que el precio se encuentre en la descripción.

# %%
def extraer_precio(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones
    precios = re.findall(r'\$?\s*(\d{1,3}(?:[.,]?\d{3})*(?:[.,]\d{2})?)\s*(mxn|usd|pesos|monto|precio|)', descripcion)
    precio = None
    for match in precios:
        numero, moneda = match
        numero = numero.replace(',', '').replace("'", '')#.replace(".",'')
        try:
            precio = float(numero)
        except ValueError:
            continue
        if precio:
            break
    return precio

# Denominación de la descripción
def extraer_denominacion(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones 
    denominaciones = re.findall(r'\b(mil|mxn|precio|pesos|monto|Mexicanos|Estadounidenses)\b', descripcion)
    return denominaciones[0] if denominaciones else None

df['precio_desc'] = df['descripcion'].apply(extraer_precio)
#df['denominacion_desc'] = df['descripcion'].apply(extraer_denominacion)
inicio = df.shape

# %%
# Aplicar colores a los valores de precio y precio_desc
def colorize_row(row):
    row_colored = row.copy()  # Crear una copia para no modificar el original
    row_colored['precio'] = f"{MAGENTA}{row['precio']}{RESET}"
    row_colored['precio_desc'] = f"{GREEN}{row['precio_desc']}{RESET}"
    return row_colored

# %% [markdown]
# ### Precio [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['precio'] == 0 ) & (df['precio_desc'].isna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas
# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    #print(row[['precio', 'precio_desc', 'url']])
    print(colorize_row(row)[['precio', 'precio_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("3. Sustituir el valor manualmente")    
    # Solicitar la opción al usuario
    option = input("Elige una opción (1 o 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'precio': ")
        df.at[idx, 'precio'] = float(new_value)
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    print("\n---\n")
print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# Eliminar registros que no recuperaron su precio ni desde la descripción

# %%
df = df[~( (df['precio'] == 0 ) & (df['precio_desc'].isna()) )]

# %% [markdown]
# ### Precio [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['precio'] == 0 ) & (df['precio_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    #print(row[['precio', 'precio_desc', 'url']])
    print(colorize_row(row)[['precio', 'precio_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'precio' por el de 'precio_desc'")
    print("3. Sustituir el valor manualmente")
    
    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'precio': ")
        df.at[idx, 'precio'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'precio'] = df.at[idx, 'precio_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Precio [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['precio']!= 0) & (df['precio_desc'].notna())) & (df['precio'] != df['precio_desc']) )] 
# Filtro dentro del estándar
totales = totales[(totales['precio_desc'] >= 250000) & (totales['precio_desc'] <= 500000000)]
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    #print(row[['precio', 'precio_desc', 'url']])
    print(colorize_row(row)[['precio', 'precio_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'precio' por el de 'precio_desc'")
    print("3. Sustituir el valor manualmente")
    
    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'precio': ")
        df.at[idx, 'precio'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'precio'] = df.at[idx, 'precio_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")

    print("\n---\n")

print("Proceso completado.")
# Out:
# Registro 22:
# precio                                                                       365000.0
# precio_desc                                                                  290000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-bcd23d0cc1f2-a5f0-2a62b82f-ae26-4ee5
# Name: 22, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 45:
# precio                                                                       402000.0
# precio_desc                                                                  250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-9301c25edeab-9356-573dce61-852c-4906
# Name: 45, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 76:
# precio                                                                      450000.0
# precio_desc                                                                 250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-fe4d11d57fc9-5cec-190bd61-b129-759c
# Name: 76, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 77:
# precio                                                                      450000.0
# precio_desc                                                                 250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-c4dd10550f5a-c153-190b898-839a-77c6
# Name: 77, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 81:
# precio                                                                      450000.0
# precio_desc                                                                 290000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-aa4f2c7c5335-8072-19116e7-9109-76b5
# Name: 81, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 116:
# precio                                                                       489000.0
# precio_desc                                                                  250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-a804d46d53ab-9ba3-7a5ac3db-9a5f-4305
# Name: 116, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 124:
# precio                                                                       499000.0
# precio_desc                                                                  250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-dde8cb7f0e22-6b9d-a3be3b16-a1eb-49b5
# Name: 124, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 141:
# precio                                                                       504000.0
# precio_desc                                                                  250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-31df0a20459d-c3b2-45855f87-ada9-444c
# Name: 141, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 142:
# precio                                                                     504000.0
# precio_desc                                                                250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-924d1a8649c-caa5-190b7fa-b39c-78ca
# Name: 142, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 207:
# precio                                                                      530000.0
# precio_desc                                                                 290000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-17d80c9ddf40-c805-354e506-b7d5-4721
# Name: 207, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 217:
# precio                                                                     532000.0
# precio_desc                                                                350000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-1542ac87b2e7-687-7dc97a1-861c-4480
# Name: 217, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 219:
# precio                                                                      535000.0
# precio_desc                                                                 250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-a7daff30214c-46fc-190a840-bf7d-7e22
# Name: 219, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 239:
# precio                                                                       546723.0
# precio_desc                                                               200000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-a8438adc509a-2d53-365bda74-91d5-40eb
# Name: 239, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 245:
# precio                                                                      550000.0
# precio_desc                                                                 250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-a60b65c66ef-c3c2-c319d7cf-9137-4abb
# Name: 245, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 250:
# precio                                                                      550000.0
# precio_desc                                                                 290000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-424d7051e88-6c6f-b88e22b4-a4ff-4d89
# Name: 250, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 251:
# precio                                                                       550000.0
# precio_desc                                                                  290000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-12ac102d4027-d3a6-82646298-ac9c-4782
# Name: 251, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 264:
# precio                                                                      553000.0
# precio_desc                                                                 350000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-396471bf951-ebe7-63c1dcbd-b4b1-420b
# Name: 264, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 268:
# precio                                                                       560000.0
# precio_desc                                                                  250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-3b70a3401db7-4c2b-20edc748-86be-4184
# Name: 268, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 278:
# precio                                                                       563000.0
# precio_desc                                                                  414848.0
# url            https://www.lamudi.com.mx/detalle/41032-73-5739d2859e41-4fc6-645a7a61-8273-4b92
# Name: 278, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 293:
# precio                                                                       574000.0
# precio_desc                                                                  474000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-4e68e85da493-3e7a-791e002f-b866-4201
# Name: 293, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 299:
# precio                                                                       575000.0
# precio_desc                                                                  350000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-4187fe1290e9-61cb-a4d9c2f5-a792-46d1
# Name: 299, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 304:
# precio                                                                       578000.0
# precio_desc                                                                  290000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-272e9dfb4b50-e533-2139c2ba-b376-5046
# Name: 304, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 313:
# precio                                                                       584000.0
# precio_desc                                                                  350000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-164e37e744f2-2479-142cba2a-b246-4afa
# Name: 313, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 336:
# precio                                                                      595000.0
# precio_desc                                                                 290000.0
# url            https://www.lamudi.com.mx/detalle/41032-73
000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-1f98105b7bd8-aeeb-190e6a6-80c9-7d10
# Name: 762, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 768:
# precio                                                                       770450.0
# precio_desc                                                                  350000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-3af2491682e7-4415-1b0154bd-822f-434c
# Name: 768, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 787:
# precio                                                                       787187.0
# precio_desc                                                               221147974.0
# url            https://www.lamudi.com.mx/detalle/41032-73-a655a40d6749-18a7-3cdac023-9ea4-4383
# Name: 787, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 790:
# precio                                                                       788000.0
# precio_desc                                                               222856964.0
# url            https://www.lamudi.com.mx/detalle/41032-73-2ceb8eae216d-5ff5-c797c817-aa3b-4986
# Name: 790, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 832:
# precio                                                                       814000.0
# precio_desc                                                                  250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-701262cfe2de-bc6c-ad4bad92-bfb9-4d90
# Name: 832, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 863:
# precio                                                                       838000.0
# precio_desc                                                                  250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-ca7d2f00d8dd-8498-6d5cdb24-9c72-48b1
# Name: 863, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 902:
# precio                                                                      865000.0
# precio_desc                                                                 290000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-4b009a2aaa06-39d9-19116f3-9bf8-7d11
# Name: 902, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 920:
# precio                                                                      878190.0
# precio_desc                                                                 350000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-bf29edd958fe-d58f-1912990-b385-77c5
# Name: 920, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 959:
# precio                                                                       911000.0
# precio_desc                                                                  250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-7142ea4a6168-7874-c36c0977-8464-4db0
# Name: 959, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 963:
# precio                                                                       915000.0
# precio_desc                                                                  280620.0
# url            https://www.lamudi.com.mx/detalle/41032-73-6d18cce7893d-62f6-9e670e2b-844f-34cc
# Name: 963, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 968:
# precio                                                                      923215.0
# precio_desc                                                                 324800.0
# url            https://www.lamudi.com.mx/detalle/41032-73-682aa4cae8d5-7bad-5a73b0d-9b3f-4e6a
# Name: 968, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 984:
# precio                                                                       935970.0
# precio_desc                                                               221147974.0
# url            https://www.lamudi.com.mx/detalle/41032-73-4bd34b96b4ab-6682-cf11c57b-91c8-416e
# Name: 984, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 990:
# precio                                                                       940000.0
# precio_desc                                                                  290000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-12dba9770875-23a7-e5a14aa6-9608-46a8
# Name: 990, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 991:
# precio                                                                       940000.0
# precio_desc                                                                  290000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-e6891965597e-a40e-c5aa5c99-ae54-48a1
# Name: 991, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 998:
# precio                                                                       943412.0
# precio_desc                                                               221147974.0
# url            https://www.lamudi.com.mx/detalle/41032-73-a92715829255-d84b-7f18dd99-b5e2-4b19
# Name: 998, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1046:
# precio                                                                       996200.0
# precio_desc                                                                  370000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-9319b03e0faf-12b5-db83beeb-b4eb-4738
# Name: 1046, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1049:
# precio                                                                     1005000.0
# precio_desc                                                                 250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-48cb0d9f1157-8b6d-b0fef78-8580-4547
# Name: 1049, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1057:
# precio                                                                      1009000.0
# precio_desc                                                                  416767.0
# url            https://www.lamudi.com.mx/detalle/41032-73-529e1ed758af-820a-1e45cc4e-abbd-4b3a
# Name: 1057, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1067:
# precio                                                                     1033200.0
# precio_desc                                                              103320000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-667bb79a1204-9645-190d853-919b-748c
# Name: 1067, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1070:
# precio                                                                      1036000.0
# precio_desc                                                                  250000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-5ebfb1b3243e-e53f-7e576182-980f-420a
# Name: 1070, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1097:
# precio                                                                      1100000.0
# precio_desc                                                                  450000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-fc77a28784ee-738b-58a6ed41-916e-4af5
# Name: 1097, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1103:
# precio                                                                     1104716.0
# precio_desc                                                                 350000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-7de3eda5d246-23fc-1910ac8-b385-77c5
# Name: 1103, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1104:
# precio                                                                     1107101.0
# precio_desc                                                                 350000.0
# url            https://www.lamudi.com.mx/detalle/41032-73
dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3269:
# precio                                                                     12800000.0
# precio_desc                                                               128000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-c73906620bbd-8c7d-fda99f0a-b795-3b52
# Name: 3269, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3286:
# precio                                                                     13000000.0
# precio_desc                                                               130000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-a61681462eee-59db-758efc95-a7d4-4f06
# Name: 3286, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3287:
# precio                                                                     13000000.0
# precio_desc                                                               130000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-9f4a84d06fad-75e8-b964f242-b38c-35fe
# Name: 3287, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3364:
# precio                                                                     16500000.0
# precio_desc                                                               165000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-c702f0be0b22-986d-f100a1b5-b339-3603
# Name: 3364, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3397:
# precio                                                                     18800000.0
# precio_desc                                                               188000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-c752bc834894-97c6-8c8d21b7-b986-3da3
# Name: 3397, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3410:
# precio                                                                     20000000.0
# precio_desc                                                               200000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-e222c196dac2-85b5-d251cf46-bd8d-4a27
# Name: 3410, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3417:
# precio                                                                     20000000.0
# precio_desc                                                               200000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-8c17c9baf4a5-183d-cb8b9aca-87a8-3e68
# Name: 3417, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3428:
# precio                                                                     24000000.0
# precio_desc                                                               240000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-4146621b09d3-e83c-e8d56ef1-b8ee-496f
# Name: 3428, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3439:
# precio                                                                     26500000.0
# precio_desc                                                                  265000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-c99f4a06b107-3265-3b9f127e-9179-4aef
# Name: 3439, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3444:
# precio                                                                     28000000.0
# precio_desc                                                                  280000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-a66256a1fd33-dec1-368f9265-90ea-352e
# Name: 3444, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3458:
# precio                                                                     32000000.0
# precio_desc                                                               320000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-389e9f769e22-5a46-7dbfc04c-828f-3279
# Name: 3458, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3462:
# precio                                                                     35000000.0
# precio_desc                                                               350000000.0
# url            https://www.lamudi.com.mx/detalle/41032-73-41297baedbd1-c107-573a762c-a3a4-477d
# Name: 3462, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'precio' por el de 'precio_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Proceso completado.

# %%
shapes = df.shape
print('La base ha quedado con: ',f'{RED}{shapes}{RESET}', 'de',f'{GREEN}{inicio}{RESET}')
# Out:
# La base ha quedado con:  (4702, 16) de (4702, 16)

# %% [markdown]
# ## b) Denominación MXN

# %% [markdown]
# SI EXISTE UNA DENOMINACIÓN QUE NO SEA MXN, SE CONVIERTA EL PRECIO

# %%
import datetime
c = CurrencyConverter() # Instancia del convertidor de monedas
def convertir_a_mxn(precio, denominacion):
    if denominacion != 'MXN':
        return int(round(c.convert(precio, denominacion, 'MXN')))
    return precio

def convertir_a_usd(precio, denominacion):
    if denominacion != 'USD':
        return round(c.convert(precio, denominacion, 'USD'))
    return precio

# Obtener la fecha actual
fecha_conversion = datetime.datetime.now().date()

# Aplicar la conversión a cada fila del DataFrame y agregar la fecha de conversión
df['precio_mxn'] = df.apply(lambda row: convertir_a_mxn(row['precio'], row['denominacion']), axis=1)
df['precio_usd'] = df.apply(lambda row: convertir_a_usd(row['precio'], row['denominacion']), axis=1)
df['fecha_conversion'] = fecha_conversion
print(df[['precio', 'denominacion', 'precio_mxn', 'precio_usd', 'fecha_conversion']].head())
# Out:
#    precio denominacion  precio_mxn  precio_usd fecha_conversion
# 0  280000          MXN      280000       15575       2024-10-04
# 1  315000          MXN      315000       17522       2024-10-04
# 2  315000          MXN      315000       17522       2024-10-04
# 3  315000          MXN      315000       17522       2024-10-04
# 4  320000          MXN      320000       17800       2024-10-04

# %% [markdown]
# ## c) Precio fuera del estandar

# %% [markdown]
# IDENTIFICAR Y ELIMINAR PROPIEDADES QUE CUENTEN CON PRECIOS BAJOS y ALTOS AL ESTANDAR

# %%
inicio = df.shape
# Eliminar los registros donde el precio es menor al estandar (250,000) y con precio_desc vacío
df = df[(df['precio'] >= 250000)] #& (df['precio_desc'].notna())]
# Eliminar los registros donde el precio es mayor al estandar (500,000,000) y con precio_desc vacío
df = df[(df['precio'] <= 500000000)] #& (df['precio_desc'].notna())] 
# Ordenar valores de manera ascendente
print(df['precio'].sort_values())
shapes = df.shape
print('La base ha quedado con: ',f'{RED}{shapes}{RESET}', 'de',f'{GREEN}{inicio}{RESET}')
# Out:
# 2          280000
# 3          280000
# 4          325000
# 5          334608
# 6          344966
#           ...
# 3627     40000000
# 3628     40000000
# 3629     41000000
# 3630     60000000
# 3631    149922400
# Name: precio, Length: 3584, dtype: int64
# La base ha quedado con:  (3584, 19) de (3586, 19)

# %% [markdown]
# ## D) Segmento o categoría

# %%
# Crear un diccionario donde las llaves son las categorías y los valores son las tuplas de rangos
rangos_precio = {
    "E1": (0, 500000),
    "E2": (500000, 750000),
    "E3": (750001, 1000000),
    "D1": (1000001, 1250000),
    "D2": (1250001, 1500000),
    "D3": (1500001, 1750000),
    "C1": (1750001, 2000000),
    "C2": (2000001, 2250000),
    "C3": (2250001, 2500000),
    "B1": (2500001, 2750000),  
    "B2": (2750001, 3000000),  
    "B3": (3000001, 3250000),  
    "A1": (3250001, 3500000),
    "A2": (3500001, 3750000),
    "A3": (3750001, 4000000),
    "S1": (4000001, 6000000),
    "S2": (6000001, 8000000),
    "S3": (8000001, 12000000),
    "L1": (12000001, 14000000),
    "L2": (14000001, 16000000),
    "L3": (16000001, 18000000),
    "L+": (18000001, 22000000),
    "ELITE": (22000001, float('inf'))
}

# Función para asignar la categoría según el precio
def asignar_categoria(precio):
    for categoria, (limite_inferior, limite_superior) in rangos_precio.items():
        if limite_inferior <= precio < limite_superior:
            return categoria
    return None  # En caso de que el precio no caiga en ningún rango (caso raro)

# Asignar la categoría a cada registro
df['categoria'] = df['precio'].apply(asignar_categoria)
print(df['categoria'].unique())
# Out:
# [None 'S1' 'A3' 'A2' 'A1' 'B3' 'B2' 'B1' 'C3' 'C2' 'C1' 'D3' 'D2' 'D1'
#  'E3' 'E2' 'E1']

# %% [markdown]
# # 2. Meses transcurridos

# %% [markdown]
# Sacar el número de meses transcurridos desde la fecha de su publicación a la actual

# %%
from datetime import datetime
# Convertir el mes abreviado en número
def month_to_int(month):
    months = ['ene', 'feb', 'mar', 'abr', 'may', 'jun', 'jul', 'ago', 'sep', 'oct', 'nov', 'dic']
    return months.index(month.lower()) + 1

# Estandarizar el formato de fecha
def standardize_date(date_str):
    # Caso 1: formato "20 abr. 2023" -> "2023-04-20"
    try:
        day, month, year = date_str.split(' ')
        month_int = month_to_int(month.replace('.', ''))  # Eliminar puntos si existen
        return f"{year}-{month_int:02d}-{int(day):02d}"
    except (ValueError, AttributeError):
        pass

    # Caso 2: formato "YYYY-MM-DD HH:MM:SS" o "YYYY-MM-DD"
    try:
        return pd.to_datetime(date_str).strftime('%Y-%m-%d')
    except (ValueError, TypeError):
        # Si no se puede convertir, devolver None
        return None

# Aplicar la función a la columna 'tiempo_de_publicacion'
df['fecha_estandarizada'] = df['tiempo_de_publicacion'].apply(standardize_date)

# Convertir a datetime y manejar errores
df['fecha_estandarizada'] = pd.to_datetime(df['fecha_estandarizada'], errors='coerce')

# Obtener la fecha actual
#fecha_actual = datetime.now().date()
fecha_actual = datetime.strptime("30/04/24", "%d/%m/%y").date()

# Función para calcular la diferencia en meses
def calcular_meses(fecha):
    if pd.isnull(fecha):
        return None
    rd = relativedelta(fecha_actual, fecha.date())
    return rd.years * 12 + rd.months

# Aplicar la función para calcular los meses transcurridos
df['meses_transcurridos'] = df['fecha_estandarizada'].apply(calcular_meses)

#Registro de fecha de conversión
df['meses_transcurridos_fecha'] = fecha_actual

# Mostrar el DataFrame con las fechas estandarizadas y meses transcurridos
print(df[['tiempo_de_publicacion', 'fecha_estandarizada', 'meses_transcurridos','meses_transcurridos_fecha']])
# Out:
#     tiempo_de_publicacion fecha_estandarizada  meses_transcurridos  \
# 0              2023-03-29          2023-03-29                   13
# 1              2023-04-28          2023-04-28                   12
# 2              2024-01-11          2024-01-11                    3
# 3              2023-09-13          2023-09-13                    7
# 4              2024-02-21          2024-02-21                    2
# ..                    ...                 ...                  ...
# 127            2024-03-04          2024-03-04                    1
# 128            2024-03-04          2024-03-04                    1
# 129            2024-02-17          2024-02-17                    2
# 130            2023-09-20          2023-09-20                    7
# 131            2024-03-04          2024-03-04                    1
#
#     meses_transcurridos_fecha
# 0                  2024-04-30
# 1                  2024-04-30
# 2                  2024-04-30
# 3                  2024-04-30
# 4                  2024-04-30
# ..                        ...
# 127                2024-04-30
# 128                2024-04-30
# 129                2024-04-30
# 130                2024-04-30
# 131                2024-04-30
#
# [132 rows x 4 columns]

# %%
fecha_actual
# Out:
# datetime.date(2024, 2, 25)

# %% [markdown]
# # 3. Tipo de propiedad

# %% [markdown]
# ## a) Estandarizar

# %%
# Convierte todos los valores a strings, maneja NaN o None como cadenas vacías
df['tipo'] = df['tipo'].astype(str)
# Convertir a minúsculas
df['tipo'] = df['tipo'].str.lower()

import unicodedata# Función para eliminar acentos
def eliminar_acentos(texto):
    # Normaliza y elimina los acentos
    texto_normalizado = unicodedata.normalize('NFKD', texto)
    return ''.join(char for char in texto_normalizado if unicodedata.category(char) != 'Mn')
df['tipo'] = df['tipo'].apply(eliminar_acentos)
# Convertir la primera letra de cada palabra a mayúscula
df['tipo'] = df['tipo'].str.title()
df['tipo'].unique()
# Out:
# array(['Casa', 'Departamento'], dtype=object)

# %% [markdown]
# ## b) Lista de tipos deseados

# %%
# Filtrar los registros según los tipos especificados
tipos_permitidos = 'Casa|Casa En Condominio|Casa En Fraccionamiento|Departamento|Penthouse|Dúplex|Loft|Estudio|Condominio Horizontal'
df = df[df['tipo'].str.contains(tipos_permitidos, na=False)]
df['tipo'].unique()
# Out:
# array(['Casa', 'Departamento'], dtype=object)

# %% [markdown]
# * Casas: Casa en condominio,
# * Departamento: Penthouse, Loft

# %% [markdown]
# ## c) Manejo de terrenos

# %% [markdown]
# Se buscan los registros que no sean las propiedades si no un solo terreno

# %%
# Filtrar los registros según las condiciones dadas
totales =df[df['descripcion'].str.contains('lote', case=False)]
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# MANEJAR PROCESO DE ELIMINACIÓN 
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(row[['descripcion']])
    print(row[['url']])
    print(f"{GREEN}\n¿Te gustaría eliminar el registro?{RESET}")
    # Solicitar la opción al usuario
    option = input("Elige una opción: Si(1) / No(0)): ").strip().lower()
    
    if option == '1':
        df.drop(idx, inplace=True)
        print(f"Registro eliminado.\n")
    else:
        print(f"Registro conservado.\n")
        print("\n---\n")
print("Proceso completado.")
# Out:
# Registro 455:
# descripcion    oportunidad inmueble adjudicadoya puedes adquirir el hogar de tus suenos a un excelente precio y de forma seguraeste inmueble es un remate bancario lo que significa que puedes obtenerlo muy por abajo de su valor comercial la propiedad se encuentra ubicada en calle 29 sur condominio hacienda santa clara col san antonio cacalotepec puebla puebla importante no se acepta ningun tipo de creditopago de contado en dos exhibiciones1er pago 320000 a la firma de contrato y 2do pago lo realiza a la entrega de la cesion de derechos ante notario publico agenda tu cita para darte detalles del proceso de adquisicion con gusto te atendere araceli casas tel ver telefono whatsapp email contactar en grupo antham nos especializamos en remates bancarios te asesoramos desde el inicio y hasta la entrega de la propiedad ref gaci
# Name: 455, dtype: object
# url    https://www.lamudi.com.mx//detalle/41032-73-bf77e7bbff24-93db-c4031523-a425-4ba2
# Name: 455, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 1345:
# descripcion    casa en venta ubicada en calle tlaxcala lote 7 manzana 25 no14110 conjunto habitacional snte pueblala casa cuenta con hall recibidor sala comedor chico bano completo cocina unicamente con alacenas recamara con closet patio de servicio y jardin trasero amplio planta alta dos habitaciones con closet bano completo con cancel cochera para tres autos con reja cisterna
# Name: 1345, dtype: object
# url    https://www.lamudi.com.mx//detalle/41032-73-77bf2da90976-af8-4bc2e0e1-a225-4301
# Name: 1345, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 1776:
# descripcion    casa en venta en heroes de puebla super precioexcelente oportunidad de inversion para negocio a precio de lote2000000casa de 1 nivel con departamento en piso 1 con entrada independienteubicada a unos metros de ciudad militar excelente ubicacion muy cerca de zona comercial en boulevard principalterreno 20484 m2construccion 220 m2planta baja garage techado para 1 auto amplia estancia sala comedor cocina medio bano 3 recamaras bano completo y 2 patios de servicioprimer nivel 1 departamento cuenta con estancia cocina1 recamara amplia y bano completo agenda tu citano desaproveches la oportunidadprecio y disponibilidad sujetos a cambios sin previo aviso las imagenes pueden ser ilustrativaste invitamos a consultar nuestro aviso de privacidadcontactar
# Name: 1776, dtype: object
# url    https://www.lamudi.com.mx//detalle/41032-73-38d4be63a50a-a16a-4bdd6405-bac7-3635
# Name: 1776, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 1792:
# descripcion    en el vibrante corazon de puebla emerge un hogar que va mas alla de las paredes es una experiencia un estilo de vida este rincon especial en san jose del puente espera transformar tus dias caracteristicas que enamoran 2 habitaciones de ensueno tu propio espacio de tranquilidad banos que cautivan modernos y llenos de confort 90 m de pura inspiracion un lienzo listo para tus mejores momentos cocina integral donde tus recetas se convierten en obras maestras luminosidad que abraza ventanas que capturan la esencia de cada dia estacionamiento privado tu vehiculo merece un hogar seguro esquina de serenidad un lote que te regala privacidad y espacio madera laminada pisos que te invitan a caminar tus suenos seguridad en cada rincon porque tu tranquilidad es primordial roof garden para instantes inolvidables celebra la vida con vistas que quitan el alientopero este hogar va mas alla de las caracteristicas es un refugio lleno de v
dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Registro 4219:
# descripcion    dentro de fraccionamiento cerrado con 11 lotes y 6 casas habitadas totalmente bardeado con amplia area verde comun vigilancia 247 calles adoquinadas servicios ocultosla casa en magnifico estado de conservacion con calidad de acabados tipo residencial cuenta con 3 nivelesen planta baja cochera techada para 2 autos medio bano de visitas oficina o cuarta recamara con closet estancia sala comedor cocina integral con isla jardin de aprox 60 m2 con terrazaen el primer nivel esta la sala de tv 3 recamaras todas con bano propio la principal con vestidor y vaporen el segundo nivel esta el roof garden con cuarto de juegos amplia sala con bar y terrazaservicios cuarto de servicio con bano cuarto de lavado bodega
# Name: 4219, dtype: object
# url    https://www.lamudi.com.mx//detalle/41032-73-a3cfeb4c9133-1a92-197b30e-860b-4539
# Name: 4219, dtype: object
#
# ¿Te gustaría eliminar el registro?
# Registro conservado.
#
#
# ---
#
# Proceso completado.

# %%
shapes = df.shape
print('La base ha quedado con: ',f'{RED}{shapes}{RESET}', 'de',f'{GREEN}{inicio}{RESET}')
# Out:
# La base ha quedado con:  (3712, 26) de (3712, 19)

# %% [markdown]
# # 4. Metros totales (terreno)

# %% [markdown]
# ## a) Metros en descripción

# %%
# Función para extraer totales de la descripción
def extraer_totales(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones de totales
    totales = re.findall(r'\b(\d+[\.,]?\d*)\s*(metros|totales|mt2)\b', descripcion)
    total = None
    for match in totales:
        numero, _ = match
        numero = numero.replace(',', '').replace("'", '')
        try:
            total = float(numero)
        except ValueError:
            continue
        if total:
            break
    return total

# Aplicar la función al DataFrame
df['totales_desc'] = df['descripcion'].apply(extraer_totales)
inicio = df.shape

# %%
# Aplicar colores a los valores de precio y precio_desc
def colorize_row(row):
    row_colored = row.copy()  # Crear una copia para no modificar el original
    row_colored['metros_total'] = f"{MAGENTA}{row['metros_total']}{RESET}"
    row_colored['totales_desc'] = f"{GREEN}{row['totales_desc']}{RESET}"
    return row_colored

# %% [markdown]
# ### Metros [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['metros_total'] == 0 ) & (df['totales_desc'].isna() | df['totales_desc']==0) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    #print(row[['metros_total', 'totales_desc', 'url']])
    print(colorize_row(row)[['metros_total', 'totales_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'metros_total' por el de 'totales_desc'")
    print("3. Sustituir el valor manualmente")
    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_total': ")
        df.at[idx, 'metros_total'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'metros_total'] = df.at[idx, 'totales_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Metros [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['metros_total'] == 0 ) & (df['totales_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    #print(row[['metros_total', 'totales_desc', 'url']])
    print(colorize_row(row)[['metros_total', 'totales_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'metros_total' por el de 'totales_desc'")
    print("3. Sustituir el valor manualmente")
    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_total': ")
        df.at[idx, 'metros_total'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'metros_total'] = df.at[idx, 'totales_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Metros [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['metros_total']!= 0) & (df['totales_desc'].notna())) & (df['metros_total'] != df['totales_desc']) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")    
    print(colorize_row(row)[['metros_total', 'totales_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'metros_total' por el de 'totales_desc'")
    print("3. Sustituir el valor manualmente")
    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        while True:
            try:
                new_value = float(input("Introduce el nuevo valor para 'metros_total': "))
                df.at[idx, 'metros_total'] = new_value
                break
            except ValueError:
                print("Por favor, introduce un número válido (entero o decimal).")
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'metros_total'] = df.at[idx, 'totales_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    print("\n---\n")

print("Proceso completado.")
# Out:
# Registro 62:
# metros_total                                                                       110
# totales_desc                                                                     400.0
# url             https://www.lamudi.com.mx/detalle/41032-73-68dbaf81f582-dbca-46fc9d62-a36e-4b31
# Name: 62, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Registro 169:
# metros_total                                                                      249
# totales_desc                                                                    140.0
# url             https://www.lamudi.com.mx/detalle/41032-73-e38de706dc5d-42c1-31986f9-90b0-1fc3
# Name: 169, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Registro 311:
# metros_total                                                                       190
# totales_desc                                                                     318.0
# url             https://www.lamudi.com.mx/detalle/41032-73-b0abadfc7706-7c4c-ebe03b27-8076-4e3c
# Name: 311, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 851:
# metros_total                                                                       120
# totales_desc                                                                     150.0
# url             https://www.lamudi.com.mx/detalle/41032-73-fd6c6e129a04-24ba-c71cbdcf-baed-4550
# Name: 851, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1048:
# metros_total                                                                       64
# totales_desc                                                                    500.0
# url             https://www.lamudi.com.mx/detalle/41032-73-83fc70c916c8-8fc9-18fa8b9-a3ec-77bb
# Name: 1048, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1064:
# metros_total                                                                       330
# totales_desc                                                                     452.0
# url             https://www.lamudi.com.mx/detalle/41032-73-4382a4d438be-fe6c-379bf341-a0cf-4399
# Name: 1064, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1072:
# metros_total                                                                        99
# totales_desc                                                                      80.0
# url             https://www.lamudi.com.mx/detalle/41032-73-ca9b44820580-9661-c0eeaf24-8182-44e4
# Name: 1072, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1077:
# metros_total                                                                       190
# totales_desc                                                                   19000.0
# url             https://www.lamudi.com.mx/detalle/41032-73-c491f10e4d07-1162-e8c430c6-b215-468b
# Name: 1077, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1095:
# metros_total                                                                        80
# totales_desc                                                                       7.0
# url             https://www.lamudi.com.mx/detalle/41032-73-c3ec381e5839-d7de-9eb6fcf1-beae-38f4
# Name: 1095, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1127:
# metros_total                                                                        78
# totales_desc                                                                      94.0
# url             https://www.lamudi.com.mx/detalle/41032-73-8b3a9fc18513-8e0e-f7762cda-98f8-43e6
# Name: 1127, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1178:
# metros_total                                                                       103
# totales_desc                                                                      15.0
# url             https://www.lamudi.com.mx/detalle/41032-73-5320c87c9b90-63e9-7931cc77-af4d-4cc9
# Name: 1178, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1202:
# metros_total                                                                        65
# totales_desc                                                                    3500.0
# url             https://www.lamudi.com.mx/detalle/41032-73-4f95e987f9aa-6031-790009d4-9bd0-4b0a
# Name: 1202, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1378:
# metros_total                                                                       100
# totales_desc                                                                       9.0
# url             https://www.lamudi.com.mx/detalle/41032-73-68640d27b930-dd20-b25643b6-bb45-4267
# Name: 1378, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1397:
# metros_total                                                                      120
# totales_desc                                                                    100.0
# url             https://www.lamudi.com.mx/detalle/41032-73-c987f0d7eb00-39c8-2407ff9-aaf2-107d
# Name: 1397, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1418:
# metros_total                                                                        80
# totales_desc                                                                      91.0
# url             https://www.lamudi.com.mx/detalle/41032-73-87cbef73579b-4483-5319dd69-8624-1ffc
# Name: 1418, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1504:
# metros_total                                                                        79
# totales_desc                                                                     127.0
# url             https://www.lamudi.com.mx/detalle/41032-73-535ee9b42a8e-2aaf-5eca8d4d-a470-4a49
# Name: 1504, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1672:
# metros_total                                                                        83
# totales_desc                                                                      30.0
# url             https://www.lamudi.com.mx/detalle/41032-73-f595f673a74c-3b9a-4cbd06ef-9de9-4a87
# Name: 1672, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1775:
# metros_total                                                                      144
# totales_desc                                                                     35.0
# url             https://www.lamudi.com.mx/detalle/41032-73-576026fd8a85-afe4-190612b-b771-7ce9
# Name: 1775, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1802:
# metros_total                                                                       106
# totales_desc                                                                     750.0
# url             https://www.lamudi.com.mx/detalle/41032-73-8d0863c07b47-e724-8cec9bfc-a150-4cdb
# Name: 1802, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1818:
# metros_total                                                                       103
# totales_desc                                                                   84180.0
# url             https://www.lamudi.com.mx/detalle/41032-73-d21e468f9baa-441c-eb40fd18-9a97-49d9
# Name: 1818, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1822:
# metros_total                                                                      102
# totales_desc                                                                    138.0
# url             https://www.lamudi.com.mx/detalle/41032-73-8eb3d1e510f3-85ab-1911571-9b77-726a
# Name: 1822, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1843:
# metros_total                                                                       105
# totales_desc                                                                   10555.0
# url             https://www.lamudi.com.mx/detalle/41032-73-dd724c986bb8-ba7f-66075655-9c3b-308b
# Name: 1843, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1865:
# metros_total                                                                       105
# totales_desc                                                                    3470.0
# url             https://www.lamudi.com.mx/detalle/41032-73-3b8096676338-1194-83acd4c9-8410-2003
# Name: 1865, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1895:
# metros_total                                                                       120
# totales_desc                                                                      15.0
# url             https://www.lamudi.com.mx/detalle/41032-73-241caa788849-b9db-8be3b9d5-98ad-4d03
# Name: 1895, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1905:
# metros_total                                                                      120
# totales_desc                                                                      8.0
# url             https://www.lamudi.com.mx/detalle/41032-73-2e414cf409ca-26b8-190d1c0-8208-77c6
# Name: 1905, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1944:
# metros_total                                                                       105
# totales_desc                                                                     138.0
# url             https://www.lamudi.com.mx/detalle/41032-73-1e7c1d5e7f48-66f5-49ba9258-b5e2-4174
# Name: 1944, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1949:
# metros_total                                                                       102
# totales_desc                                                                     138.0
# url             https://www.lamudi.com.mx/detalle/41032-73-aeb821f9687f-4549-749e4840-9d1f-4d4a
# Name: 1949, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1962:
# metros_total                                                                       184
# totales_desc                                                                      22.0
# url             https://www.lamudi.com.mx/detalle/41032-73-535978ec43fe-386c-d826835e-90a4-3ef8
# Name: 1962, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 1969:
# metros_total                                                                      103
# totales_desc                                                                    138.0
# url             https://www.lamudi.com.mx/detalle/41032-73-914543677d34-5665-1911577-9b77-726a
# Name: 1969, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2001:
# metros_total                                                                       117
# totales_desc                                                                     150.0
# url             https://www.lamudi.com.mx/detalle/41032-73-fc87fb7ce55a-6e16-aaf71f15-a1aa-3582
# Name: 2001, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2031:
# metros_total                                                                      192
# totales_desc                                                                    230.0
# url             https://www.lamudi.com.mx/detalle/41032-73-f926a3b377c6-b747-18fde17-94d0-71cd
# Name: 2031, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2120:
# metros_total                                                                     250
# totales_desc                                                                   385.0
# url             https://www.lamudi.com.mx/detalle/41032-73-c2758992d7f-2a75-19138f7-96dc-78d5
# Name: 2120, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2179:
# metros_total                                                                       150
# totales_desc                                                                     220.0
# url             https://www.lamudi.com.mx/detalle/41032-73-fa824f5a0b8d-8bd1-6e98f316-a9e4-34e3
# Name: 2179, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2192:
# metros_total                                                                       200
# totales_desc                                                                   20020.0
# url             https://www.lamudi.com.mx/detalle/41032-73-8d8c2643830e-c46c-2cc52ef7-987b-3a5d
# Name: 2192, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2200:
# metros_total                                                                       150
# totales_desc                                                                     220.0
# url             https://www.lamudi.com.mx/detalle/41032-73-3d901f16faa1-9972-d8d7465a-abaf-365b
# Name: 2200, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2331:
# metros_total                                                                        81
# totales_desc                                                                     160.0
# url             https://www.lamudi.com.mx/detalle/41032-73-e1fcf7e0a3de-2e2c-4a7abbcd-b4d8-5015
# Name: 2331, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2397:
# metros_total                                                                       180
# totales_desc                                                                     228.0
# url             https://www.lamudi.com.mx/detalle/41032-73-a4b6b704724d-6975-7477a7b7-b9b6-311f
# Name: 2397, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2415:
# metros_total                                                                       241
# totales_desc                                                                     282.0
# url             https://www.lamudi.com.mx/detalle/41032-73-953d770c33b3-38cc-10a92029-b325-106f
# Name: 2415, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2431:
# metros_total                                                                      218
# totales_desc                                                                   5000.0
# url             https://www.lamudi.com.mx/detalle/41032-73-b3dd1c6cdee-66d9-a17b9b88-a01f-3833
# Name: 2431, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2435:
# metros_total                                                                       231
# totales_desc                                                                    5000.0
# url             https://www.lamudi.com.mx/detalle/41032-73-220b9cedc3df-bfa9-31917811-97c6-33e6
# Name: 2435, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2436:
# metros_total                                                                       218
# totales_desc                                                                    5000.0
# url             https://www.lamudi.com.mx/detalle/41032-73-aae4d30b5180-2bba-2f2534f1-b587-3143
# Name: 2436, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2439:
# metros_total                                                                       218
# totales_desc                                                                    5000.0
# url             https://www.lamudi.com.mx/detalle/41032-73-aa9a65cedb4b-5f03-ca53eb8f-b2c9-3716
# Name: 2439, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2440:
# metros_total                                                                       231
# totales_desc                                                                    5000.0
# url             https://www.lamudi.com.mx/detalle/41032-73-3547193e3419-a275-1f0da100-bff8-33b8
# Name: 2440, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2441:
# metros_total                                                                      231
# totales_desc                                                                   5000.0
# url             https://www.lamudi.com.mx/detalle/41032-73-b070d38c8cf9-3319-26d3d87-8e50-3749
# Name: 2441, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2569:
# metros_total                                                                      411
# totales_desc                                                                    250.0
# url             https://www.lamudi.com.mx/detalle/41032-73-e2f00a1c04b2-8be3-9d29371-878c-4922
# Name: 2569, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2587:
# metros_total                                                                       265
# totales_desc                                                                   17473.0
# url             https://www.lamudi.com.mx/detalle/41032-73-2fb246e437f5-3e05-a16ca8b3-bb8f-3b3e
# Name: 2587, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2650:
# metros_total                                                                     184
# totales_desc                                                                   600.0
# url             https://www.lamudi.com.mx/detalle/41032-73-7c52ca44b90-caa1-18f5c6e-b75a-7b09
# Name: 2650, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2667:
# metros_total                                                                       393
# totales_desc                                                                     100.0
# url             https://www.lamudi.com.mx/detalle/41032-73-3db23c170e8c-8156-d5cfc6b0-87b1-399b
# Name: 2667, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2783:
# metros_total                                                                       200
# totales_desc                                                                     359.0
# url             https://www.lamudi.com.mx/detalle/41032-73-c9cb897fc163-236c-99a0aaab-ae03-48be
# Name: 2783, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2861:
# metros_total                                                                       165
# totales_desc                                                                     250.0
# url             https://www.lamudi.com.mx/detalle/41032-73-9aea03010411-e2cf-34d40019-b3d9-37f9
# Name: 2861, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2872:
# metros_total                                                                      298
# totales_desc                                                                    144.0
# url             https://www.lamudi.com.mx/detalle/41032-73-c42d8e9f464c-12bf-18f7e93-ad69-7a79
# Name: 2872, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2877:
# metros_total                                                                       244
# totales_desc                                                                     317.0
# url             https://www.lamudi.com.mx/detalle/41032-73-1d98bf9aa6d9-8e8a-a0791a09-a4ac-3c1b
# Name: 2877, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2900:
# metros_total                                                                       258
# totales_desc                                                                      63.0
# url             https://www.lamudi.com.mx/detalle/41032-73-b4d045b59eaa-3a65-847c0347-8ae3-47a3
# Name: 2900, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2901:
# metros_total                                                                      258
# totales_desc                                                                     63.0
# url             https://www.lamudi.com.mx/detalle/41032-73-859b3d63fc7c-898-ca79bd09-9ede-1fef
# Name: 2901, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2903:
# metros_total                                                                      258
# totales_desc                                                                     63.0
# url             https://www.lamudi.com.mx/detalle/41032-73-859b3d63fc7c-88b-e1010639-9ede-1fef
# Name: 2903, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2917:
# metros_total                                                                       331
# totales_desc                                                                     300.0
# url             https://www.lamudi.com.mx/detalle/41032-73-da448af16c26-562f-138410ac-94fd-3cea
# Name: 2917, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2918:
# metros_total                                                                       331
# totales_desc                                                                     300.0
# url             https://www.lamudi.com.mx/detalle/41032-73-fef4c0d4500f-c6ee-12c23a9d-9fa4-343d
# Name: 2918, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2940:
# metros_total                                                                       375
# totales_desc                                                                     180.0
# url             https://www.lamudi.com.mx/detalle/41032-73-dde9ff2dc78f-7a75-6f134541-bf06-3e58
# Name: 2940, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2944:
# metros_total                                                                    49085
# totales_desc                                                                     31.0
# url             https://www.lamudi.com.mx/detalle/41032-73-306541263a06-4a86-1d8240f-b976-35bd
# Name: 2944, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2967:
# metros_total                                                                       465
# totales_desc                                                                     219.0
# url             https://www.lamudi.com.mx/detalle/41032-73-e5a8ce6871ec-5c29-38f2870d-80f9-44ac
# Name: 2967, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 2995:
# metros_total                                                                     530
# totales_desc                                                                    25.0
# url             https://www.lamudi.com.mx/detalle/41032-73-be293b3a41a0-d9-8dd69ccc-a274-4e7e
# Name: 2995, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3084:
# metros_total                                                                       871
# totales_desc                                                                   87199.0
# url             https://www.lamudi.com.mx/detalle/41032-73-3e549c617f41-7dd3-2c269aba-a1c8-41b3
# Name: 3084, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3174:
# metros_total                                                                       500
# totales_desc                                                                     100.0
# url             https://www.lamudi.com.mx/detalle/41032-73-886494c6d2c7-a998-189b9987-b2f0-3deb
# Name: 3174, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3201:
# metros_total                                                                       537
# totales_desc                                                                     592.0
# url             https://www.lamudi.com.mx/detalle/41032-73-a08f574f1584-7b9b-eabc2fa7-afd9-3c53
# Name: 3201, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3206:
# metros_total                                                                       400
# totales_desc                                                                      70.0
# url             https://www.lamudi.com.mx/detalle/41032-73-346a2d358dab-e4a7-67b346a0-ac74-3e92
# Name: 3206, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3221:
# metros_total                                                                       680
# totales_desc                                                                     300.0
# url             https://www.lamudi.com.mx/detalle/41032-73-933067e00f53-f9ce-f2c0b419-8578-1f79
# Name: 3221, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3223:
# metros_total                                                                       600
# totales_desc                                                                     300.0
# url             https://www.lamudi.com.mx/detalle/41032-73-d0b70085510b-7131-b86bd282-9d31-4980
# Name: 3223, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3225:
# metros_total                                                                       690
# totales_desc                                                                      20.0
# url             https://www.lamudi.com.mx/detalle/41032-73-6f8b04dab01c-1772-cf1e418d-8dbf-4ff4
# Name: 3225, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3248:
# metros_total                                                                       427
# totales_desc                                                                      70.0
# url             https://www.lamudi.com.mx/detalle/41032-73-bf9a883cd355-4e21-ec03ca19-865d-1237
# Name: 3248, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3253:
# metros_total                                                                      1214
# totales_desc                                                                     700.0
# url             https://www.lamudi.com.mx/detalle/41032-73-35fef7f571fb-136f-8981a3cf-aced-4afb
# Name: 3253, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3267:
# metros_total                                                                       426
# totales_desc                                                                      80.0
# url             https://www.lamudi.com.mx/detalle/41032-73-8cfb68c3a35d-1e15-c70341ac-93fe-3749
# Name: 3267, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3269:
# metros_total                                                                      2700
# totales_desc                                                                  478134.0
# url             https://www.lamudi.com.mx/detalle/41032-73-c73906620bbd-8c7d-fda99f0a-b795-3b52
# Name: 3269, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3325:
# metros_total                                                                       891
# totales_desc                                                                     900.0
# url             https://www.lamudi.com.mx/detalle/41032-73-298420eb4858-9700-67b94206-9c08-4470
# Name: 3325, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3326:
# metros_total                                                                       891
# totales_desc                                                                     200.0
# url             https://www.lamudi.com.mx/detalle/41032-73-d378e333e9ab-6ac9-c62a63b9-bf71-201c
# Name: 3326, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3330:
# metros_total                                                                       690
# totales_desc                                                                     891.0
# url             https://www.lamudi.com.mx/detalle/41032-73-551c5d53bf1d-c77f-58abf59a-81cc-306d
# Name: 3330, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3364:
# metros_total                                                                       410
# totales_desc                                                                     100.0
# url             https://www.lamudi.com.mx/detalle/41032-73-c702f0be0b22-986d-f100a1b5-b339-3603
# Name: 3364, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3397:
# metros_total                                                                       478
# totales_desc                                                                  478134.0
# url             https://www.lamudi.com.mx/detalle/41032-73-c752bc834894-97c6-8c8d21b7-b986-3da3
# Name: 3397, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3398:
# metros_total                                                                       840
# totales_desc                                                                     200.0
# url             https://www.lamudi.com.mx/detalle/41032-73-b40a341eec20-d49b-9d59de81-8c43-450c
# Name: 3398, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3406:
# metros_total                                                                       80
# totales_desc                                                                    200.0
# url             https://www.lamudi.com.mx/detalle/41032-73-2e349a2f2862-10b1-19129dd-af68-7875
# Name: 3406, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3407:
# metros_total                                                                      80
# totales_desc                                                                   200.0
# url             https://www.lamudi.com.mx/detalle/41032-73-ed665a5700c3-f5e-19129dd-899d-7ffd
# Name: 3407, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3458:
# metros_total                                                                       770
# totales_desc                                                                     750.0
# url             https://www.lamudi.com.mx/detalle/41032-73-389e9f769e22-5a46-7dbfc04c-828f-3279
# Name: 3458, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Registro 3474:
# metros_total                                                                     2300
# totales_desc                                                                   1000.0
# url             https://www.lamudi.com.mx/detalle/41032-73-7b53712ff3fc-b0f-1008b1c9-a5ab-1f61
# Name: 3474, dtype: object
#
# ¿Qué acción te gustaría realizar?
# 1. Pasar al siguiente registro
# 2. Sustituir el valor de 'metros_total' por el de 'totales_desc'
# 3. Sustituir el valor manualmente
# Opción no válida. Pasando al siguiente registro...
#
# ---
#
# Proceso completado.

# %%
shapes = df.shape
print('La base ha quedado con: ',f'{RED}{shapes}{RESET}', 'de',f'{GREEN}{inicio}{RESET}')
# Out:
# La base ha quedado con:  (3476, 24) de (3476, 24)

# %% [markdown]
# ## b) Manejo por rangos de UMA

# %% [markdown]
# Paso opcional por si no se espera cambiar el precio por el que se tenga en descripción

# %% [markdown]
# Rangos
# * 118 UMAS = 40m2
# * 118.1-200 = 50m2
# * 200.1-350 = 71m2
# * 350.1-750 = 102m2
# * 750.1-1500 = 156m2

# %% [markdown]
# ### DF cuando ambas columnas son 0 o vacíos

# %%
# Rangos de UMAs y sus equivalencias en m²
umas_to_m2 = [
    (118, 40),
    (200, 50),
    (350, 71),
    (750, 102),
    (1500, 156)
]
valor_uma = 108.57

# Convertir MXN a UMAs
def precio_a_umas(precio, valor_uma):
    return precio / valor_uma

# Asignar m² basado en el precio en UMAs
def asignar_m2(precio_umas):
    for upper_bound, m2 in umas_to_m2:
        if precio_umas <= upper_bound:
            return m2
    return None  # En caso de que el precio en UMAs sea mayor al máximo definido

# Actualizar los registros con 'metros_total' igual a 0 y 'totales_desc' es NaN
def actualizar_metros_total(row):
    if row['metros_total'] == 0 and pd.isna(row['totales_desc']):
        precio_umas = precio_a_umas(row['precio'], valor_uma)
        row['metros_total'] = asignar_m2(precio_umas)
    return row

totales = df[( (df['metros_total'] == 0 ) & (df['totales_desc'].isna() | df['totales_desc']==0) )] 
totales = df.apply(actualizar_metros_total, axis=1)
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

#df = df.apply(actualizar_metros_total, axis=1)
print(totales[['metros_total', 'totales_desc', 'url']])

# %%
# Si se aceptan los cambios:
df = df.apply(actualizar_metros_total, axis=1)

# %% [markdown]
# # 5. M2 construidos

# %% [markdown]
# ## a) M-construidos en descripción

# %%
# Función para extraer totales de la descripción
def extraer_totales(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones de totales
    totales = re.findall(r'\b(\d+[\.,]?\d*)\s*(metros|construidos)\b', descripcion)
    total = None
    for match in totales:
        numero, _ = match
        numero = numero.replace(',', '').replace("'", '')
        try:
            total = float(numero)
        except ValueError:
            continue
        if total:
            break
    return total

# Aplicar la función al DataFrame
df['construidos_desc'] = df['descripcion'].apply(extraer_totales)
inicio = df.shape

# %%
# Aplicar colores a los valores de precio y precio_desc
def colorize_row(row):
    row_colored = row.copy()  # Crear una copia para no modificar el original
    row_colored['metros_construido'] = f"{MAGENTA}{row['metros_construido']}{RESET}"
    row_colored['construidos_desc'] = f"{GREEN}{row['construidos_desc']}{RESET}"
    return row_colored

# %% [markdown]
# ### Metros [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['metros_construido'] == 0 ) & (df['construidos_desc'].isna() | df['construidos_desc']==0) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    #print(row[['metros_construido', 'construidos_desc', 'url']])
    print(colorize_row(row)[['metros_construido', 'construidos_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'")
    print("3. Sustituir el valor manualmente")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_construido': ")
        df.at[idx, 'metros_construido'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_construido' por 'construidos_desc'
        df.at[idx, 'metros_construido'] = df.at[idx, 'construidos_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Metros [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['metros_construido'] == 0 ) & (df['construidos_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    #print(row[['metros_construido', 'construidos_desc', 'url']])
    print(colorize_row(row)[['metros_construido', 'construidos_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'")
    print("3. Sustituir el valor manualmente")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_construido': ")
        df.at[idx, 'metros_construido'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_construido' por 'construidos_desc'
        df.at[idx, 'metros_construido'] = df.at[idx, 'construidos_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Metros [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['metros_construido']!= 0) & (df['construidos_desc'].notna())) & (df['metros_construido'] != df['construidos_desc']) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    #print(row[['metros_construido', 'construidos_desc', 'url']])
    print(colorize_row(row)[['metros_construido', 'construidos_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'metros_construido' por el de 'construidos_desc'")
    print("3. Sustituir el valor manualmente")
    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'metros_construido': ")
        try:
            df.at[idx, 'metros_construido'] = float(new_value)
        except ValueError:
            print("Valor no válido. Debe ser un número. Pasando al siguiente registro...")
    elif option == '2':
        # Sustituir el valor de 'metros_construido' por 'construidos_desc'
        df.at[idx, 'metros_construido'] = df.at[idx, 'construidos_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")

# %%
shapes = df.shape
print('La base ha quedado con: ',f'{RED}{shapes}{RESET}', 'de',f'{GREEN}{inicio}{RESET}')

# %% [markdown]
# # 6. Precio / m2

# %% [markdown]
# ## M2 Totales (terreno)

# %%
# Calcular precio por metro cuadrado del terreno
df['precio_m2_terreno'] = df['precio']/df['metros_total']

# %% [markdown]
# ## M2 Construidos

# %%
# Calcular precio por metro cuadrado de la cosntrucción
df['precio_m2_construido'] = df['precio']/df['metros_construido']

# %% [markdown]
# # 7. Estacionamientos

# %% [markdown]
# ## a) Estacionamientos descritos

# %% [markdown]
# Asigna las diferentes maneras en las que puede encontrarse descrito el espacio de estacionamientos

# %%
# Función para extraer estacionamientos de la descripción
def extraer_coches(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones de totales
    totales = re.findall(r'\b(\d+[\.,]?\d*)\s*(|cochera|garage|carros|carro|coche|coches|autos|automóviles|automóvil|auto|lugares de estacionamiento)\b', descripcion)
    total = None
    for match in totales:
        numero, _ = match
        numero = numero.replace(',', '').replace("'", '').replace('.','')
        try:
            total = float(numero)
        except ValueError:
            continue
        if total:
            break
    return total

# Aplicar la función al DataFrame
df['estacionamiento_desc'] = df['descripcion'].apply(extraer_coches)
inicio = df.shape

# %%
# Aplicar colores a los valores de precio y precio_desc
def colorize_row(row):
    row_colored = row.copy()  # Crear una copia para no modificar el original
    row_colored['estacionamientos'] = f"{MAGENTA}{row['estacionamientos']}{RESET}"
    row_colored['estacionamiento_desc'] = f"{GREEN}{row['estacionamiento_desc']}{RESET}"
    return row_colored

# %% [markdown]
# ### Estacionamientos [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['estacionamientos']==0) & (df['estacionamiento_desc'].isna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    #print(row[['url']])
    print(colorize_row(row)[['estacionamientos', 'estacionamiento_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    #print("2. Sustituir el valor de 'precio' por el de 'precio_desc'")
    print("3. Sustituir el valor manualmente")
    
    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'estacionamientos': ")
        df.at[idx, 'estacionamientos'] = int(new_value)
    #elif option == '2':
        # Sustituir el valor de 'estacionamientos' por 'estacionamiento_desc'
        #df.at[idx, 'estacionamientos'] = df.at[idx, 'estacionamiento_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")

    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Estacionamientos [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['estacionamientos']==0) & (df['estacionamiento_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    #print(row[['estacionamientos', 'estacionamiento_desc', 'url']])
    print(colorize_row(row)[['estacionamientos', 'estacionamiento_desc', 'url']])

    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'")
    print("3. Sustituir el valor manualmente")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'estacionamientos': ")
        df.at[idx, 'estacionamientos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'estacionamientos'] = df.at[idx, 'estacionamiento_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Estacionamientos [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['estacionamientos']!=0) & (df['estacionamiento_desc'].notna())) & (df['estacionamientos'] != df['estacionamiento_desc']) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    #print(row[['estacionamientos', 'estacionamiento_desc', 'url']])
    print(colorize_row(row)[['estacionamientos', 'estacionamiento_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'estacionamientos' por el de 'estacionamiento_desc'")
    print("3. Sustituir el valor manualmente")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'estacionamientos': ")
        df.at[idx, 'estacionamientos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'estacionamientos'] = df.at[idx, 'estacionamiento_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")

# %%
shapes = df.shape
print('La base ha quedado con: ',f'{RED}{shapes}{RESET}', 'de',f'{GREEN}{inicio}{RESET}')

# %% [markdown]
# ## b) Mantener rango de estacionamientos < 5 (mínimo 1)

# %%
df = df[df['estacionamientos'] <= 8]
#df[['estacionamientos','estacionamiento_desc','url']]

# %% [markdown]
# # 8. Recámaras

# %% [markdown]
# ## a) Recámaras en descripción

# %%
# Función para extraer cantidad de recamaras en descripción
def extraer_recamaras(descripcion):
    descripcion = descripcion.lower()
    # Buscar patrones de totales
    totales = re.findall(r'\b(\d+[\.,]?\d*)\s*(recamara|recamaras|habitaciones|dormitorio|dormitorios)\b', descripcion)
    total = None
    for match in totales:
        numero, _ = match
        numero = numero.replace(',', '').replace("'", '')
        try:
            total = float(numero)
        except ValueError:
            continue
        if total:
            break
    return total

# Aplicar la función al DataFrame
df['recamaras_desc'] = df['descripcion'].apply(extraer_recamaras)
inicio = df.shape

# %%
# Aplicar colores a los valores de precio y precio_desc
def colorize_row(row):
    row_colored = row.copy()  # Crear una copia para no modificar el original
    row_colored['recamaras'] = f"{MAGENTA}{row['recamaras']}{RESET}"
    row_colored['recamaras_desc'] = f"{GREEN}{row['recamaras_desc']}{RESET}"
    return row_colored

# %% [markdown]
# ### Recámaras [0 / 0]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[ (df['recamaras'] == 0 ) & (df['recamaras_desc'].isna()) ] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    #print(row[['url']])
    print(colorize_row(row)[['recamaras', 'recamaras_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("3. Sustituir el valor manualmente")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'recamaras': ")
        df.at[idx, 'recamaras'] = float(new_value)
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Recámaras [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['recamaras']==0) & (df['recamaras_desc'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(colorize_row(row)[['recamaras', 'recamaras_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'recamaras' por el de 'recamaras_desc'")
    print("3. Sustituir el valor manualmente")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'recamaras': ")
        df.at[idx, 'recamaras'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'recamaras'] = df.at[idx, 'recamaras_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# ### Recámaras [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['recamaras']!=0) & (df['recamaras_desc'].notna()) ) & (df['recamaras'] != df['recamaras_desc'])] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(colorize_row(row)[['recamaras', 'recamaras_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'recamaras' por el de 'recamaras_desc'")
    print("3. Sustituir el valor manualmente")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'recamaras': ")
        df.at[idx, 'recamaras'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'metros_total' por 'totales_desc'
        df.at[idx, 'recamaras'] = df.at[idx, 'recamaras_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")

# %%
shapes = df.shape
print('La base ha quedado con: ',f'{RED}{shapes}{RESET}', 'de',f'{GREEN}{inicio}{RESET}')

# %% [markdown]
# ## b) Mantener rango de recámaras <= 7

# %%
print(df['recamaras'].unique())
df = df[(df['recamaras'] <= 7)] 
#print(df[['recamaras','recamaras_desc','url']])

# %% [markdown]
# # 9. Baños

# %% [markdown]
# ## a) Baños en descripción

# %% [markdown]
# Manejando tanto los completos como los medios

# %%
# Extraer la cantidad de baños y medios baños en la descripción
def extraer_baños(descripcion):
    descripcion = descripcion.lower()
    
    # Buscar patrones de baños completos
    completos = re.findall(r'\b(\d+[\.,]?\d*)\s*baños?\b', descripcion)
    total_completos = sum([float(match.replace(',', '').replace("'", '')) for match in completos])
    
    # Buscar patrones de medios baños (1/2 baño)
    medios = re.findall(r'\b(\d+[\.,]?\d*)\s*medios?\s*baños?\b', descripcion)
    total_medios = sum([float(match.replace(',', '').replace("'", '')) for match in medios])
    
    # Retornar como un diccionario o una tupla
    return {'completos': total_completos, 'medios': total_medios}

# Aplicar la función al DataFrame
df['baños_desc'] = df['descripcion'].apply(extraer_baños)

# Si deseas separar en dos columnas distintas:
df['baños_completos'] = df['baños_desc'].apply(lambda x: x['completos'] if x else 0)
df['medios_baños'] = df['baños_desc'].apply(lambda x: x['medios'] if x else 0)

# %% [markdown]
# ### Baños

# %%
# Aplicar colores a los valores de precio y precio_desc
def colorize_row(row):
    row_colored = row.copy()  # Crear una copia para no modificar el original
    row_colored['banos'] = f"{MAGENTA}{row['banos']}{RESET}"
    row_colored['baños_completos'] = f"{GREEN}{row['baños_completos']}{RESET}"
    return row_colored
inicio = df.shape

# %% [markdown]
# #### [0 / 0]

# %% [markdown]
# Poner como mínimo para el registro 1 en baños, pero si cuenta con medio baño en descripción que se le asigne ese valor.

# %%
# Filtrar los registros según las condiciones dadas
totales = df[(df['banos'] == 0) & (df['baños_completos'].isna())]
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(colorize_row(row)[['banos', 'baños_completos', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    #print("2. Asignar 1 como mínimo y pasar al siguiente registro")
    print("3. Sustituir el valor manualmente")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'banos': ")
        df.at[idx, 'banos'] = float(new_value)
    elif option == '1':
        continue  # Pasar al siguiente registro
    #elif option == '2':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'banos'] = 1
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")
# Out:
# Proceso completado.

# %% [markdown]
# #### [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['banos']==0) & (df['baños_completos'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(colorize_row(row)[['banos', 'baños_completos', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'banos' por el de 'baños_completos'")
    print("3. Sustituir el valor manualmente")
    #print("4. Asignar 1 como mínimo y pasar al siguiente registro")
    

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2 | 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'banos': ")
        df.at[idx, 'banos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'banos' por 'baños_completos'
        df.at[idx, 'banos'] = df.at[idx, 'baños_completos']
    elif option=='1':
        continue
    #elif option == '4':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'banos'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# #### [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['banos']!=0) & (df['baños_completos'].notna())) & (df['banos'] != df['baños_completos']))] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(colorize_row(row)[['banos', 'baños_completos', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'banos' por el de 'baños_completos'")
    print("3. Sustituir el valor manualmente")
    #print("4. Asignar 1 como mínimo y pasar al siguiente registro")
    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2 | 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'banos': ")
        df.at[idx, 'banos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'banos' por 'baños_completos'
        df.at[idx, 'banos'] = df.at[idx, 'baños_completos']
    elif option == '1':
        continue
    #elif option == '4':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'banos'] = 1
        #continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")

# %%
shapes = df.shape
print('La base ha quedado con: ',f'{RED}{shapes}{RESET}', 'de',f'{GREEN}{inicio}{RESET}')

# %% [markdown]
# ### Medio baños

# %%
# Aplicar colores a los valores de precio y precio_desc
def colorize_row(row):
    row_colored = row.copy()  # Crear una copia para no modificar el original
    row_colored['medio_banos'] = f"{MAGENTA}{row['medio_banos']}{RESET}"
    row_colored['medios_baños'] = f"{GREEN}{row['medios_baños']}{RESET}"
    return row_colored
inicio = df.shape

# %% [markdown]
# #### [0 / 0]

# %% [markdown]
# Poner como mínimo para el registro 1 en baños, pero si cuenta con valor en descripción que se le asigne ese valor.

# %%
# Filtrar los registros según las condiciones dadas
totales = df[(df['medio_banos'] == 0) & (df['medios_baños'].isna())]
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(colorize_row(row)[['medio_banos', 'medios_baños', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    #print("2. Asignar 1 como mínimo y pasar al siguiente registro")
    print("3. Sustituir el valor manualmente")
    
    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'medio_banos': ")
        df.at[idx, 'medio_banos'] = float(new_value)
    #elif option == '2':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'banos'] = 1
    elif option=='1':
        continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# #### [0 / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( (df['medio_banos']==0) & (df['medios_baños'].notna()) )] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(colorize_row(row)[['medio_banos', 'medios_baños', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'medio_banos' por el de 'medios_baños'")
    #print("3. Asignar 1 como mínimo y pasar al siguiente registro")
    print("3. Sustituir el valor manualmente")
    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2 | 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'medio_banos': ")
        df.at[idx, 'medio_banos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'medio_banos' por 'medios_baños'
        df.at[idx, 'medio_banos'] = df.at[idx, 'medios_baños']
    #elif option == '3':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'medio_baños'] = 1
    elif option=='1':
        continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# #### [# / #]

# %%
# Filtrar los registros según las condiciones dadas
totales = df[( ((df['medio_banos']!=0) & (df['medios_baños'].notna())) & (df['medio_banos'] != df['medios_baños']))] 
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in totales.iterrows():
    print(f"Registro {idx}:")
    print(colorize_row(row)[['medio_banos', 'medios_baños', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'medio_banos' por el de 'medios_baños'")
    #print("4. Asignar 1 como mínimo y pasar al siguiente registro")
    print("3. Sustituir el valor manualmente")

    # Solicitar la opción al usuario
    option = input("Elige una opción (1 | 2 | 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'medio_banos': ")
        df.at[idx, 'medio_banos'] = float(new_value)
    elif option == '2':
        # Sustituir el valor de 'medio_baños' por 'medios_baños'
        df.at[idx, 'medio_banos'] = df.at[idx, 'medios_baños']
    #elif option == '4':
        # Asignar valor de 1 como mínimo
        #df.at[idx, 'medio_baños'] = 1
    elif option=='1':
        continue  # Pasar al siguiente registro
    else:
        continue  # Pasar al siguiente registro

    print("\n---\n")

print("Proceso completado.")

# %%
shapes = df.shape
print('La base ha quedado con: ',f'{RED}{shapes}{RESET}', 'de',f'{GREEN}{inicio}{RESET}')

# %% [markdown]
# ## B) Total de baños

# %%
# Make the medio_baños and banos sum
# 'medio_baños', divididos entre 2 para representar medios
df['bano_total'] = df['banos'] + (df['medio_banos'] / 2)
df['bano_total'] = df['bano_total'].round(1)  # Round the total, not just 'banos'
print(df[['banos', 'medio_banos', 'bano_total']].head())
# Out:
#    banos  medio_banos  bano_total
# 0      1            0         1.0
# 1      1            0         1.0
# 2      1            0         1.0
# 3      2            0         2.0
# 4      2            0         2.0

# %% [markdown]
# # 10. Ubicación

# %% [markdown]
# ## a) Desde descripción
# #### ** Este paso aún necesita actualización en función de asignar los Códigos postales **

# %%
df[['lugar', 'Colonia', 'CP', 'ubicacion',]]
# Out:
#                  lugar                     Colonia       CP  \
# 0                  NaN           bosques del pilar  72310.0
# 1                  NaN             plazas amalucan  72310.0
# 2                  NaN             plazas amalucan  72310.0
# 3                  NaN             plazas amalucan  72310.0
# 4     Héroes de Puebla            héroes de puebla  72494.0
# ...                ...                         ...      ...
# 4448               NaN     residencial camino real  72837.0
# 4449               NaN  zona comercial angelópolis      NaN
# 4451               NaN                      la paz  72160.0
# 4452               NaN               arcos del sur  72176.0
# 4453               NaN                      la paz  72160.0
#
#                                              ubicacion
# 0                        Puebla Centro, Puebla, Puebla
# 1                      Plazas Amalucan, Puebla, Puebla
# 2                      Plazas Amalucan, Puebla, Puebla
# 3                      Plazas Amalucan, Puebla, Puebla
# 4     Fraccionamiento Héroes de Puebla, Puebla, Puebla
# ...                                                ...
# 4448           Residencial Camino Real, Puebla, Puebla
# 4449        Zona Comercial Angelópolis, Puebla, Puebla
# 4451                            La Paz, Puebla, Puebla
# 4452                     Arcos del Sur, Puebla, Puebla
# 4453                            La Paz, Puebla, Puebla
#
# [3712 rows x 4 columns]

# %%
# Función para extraer ubicación de la descripción
def extraer_ubicacion(descripcion):
    descripcion = descripcion.lower()
    # Patrones para buscar ubicaciones comunes
    patrones = [
        r'(?:ubicad[oa] en|en) ([\w\s]+(?:,\s*[\w\s]+){0,2})',
        r'(?:calle|avenida|av\.) ([\w\s]+(?:,\s*[\w\s]+){0,2})',
        r'(?:colonia|col\.) ([\w\s]+(?:,\s*[\w\s]+){0,2})',
        r'(?:fraccionamiento|fracc\.) ([\w\s]+(?:,\s*[\w\s]+){0,2})'
    ]
    2.
    for patron in patrones:
        match = re.search(patron, descripcion)
        if match:
            return match.group(1).strip().title()
    
    return None

# Aplicar la función al DataFrame
df['ubicacion_desc'] = df['descripcion'].apply(extraer_ubicacion)

# %% [markdown]
# #### Cuando la ubicación dice centro:

# %%
# Filtrar los registros donde la ubicación contiene la palabra "centro"
df_centro = df[df['ubicacion'].str.contains('centro|Centro', case=False, na=False)]
num_registros_centro = len(df_centro)

print(f"Número de registros que contienen 'centro' en la ubicación:",f"{RED} {num_registros_centro}{RESET}")
# Out:
# Número de registros que contienen 'centro' en la ubicación:  142

# %%
# Aplicar colores a los valores de precio y precio_desc
def colorize_row(row):
    row_colored = row.copy()  # Crear una copia para no modificar el original
    row_colored['ubicacion'] = f"{MAGENTA}{row['ubicacion']}{RESET}"
    row_colored['ubicacion_desc'] = f"{GREEN}{row['ubicacion_desc']}{RESET}"
    return row_colored
inicio = df.shape

# %%
pd.set_option('display.max_colwidth', None) # Mostrar URLs completas

# Iterar sobre los registros filtrados
for idx, row in df_centro.iterrows():
    print(f"Registro {idx}:")    
    #print(row[['ubicacion', 'ubicacion_desc', 'url']])
    print(colorize_row(row)[['ubicacion', 'ubicacion_desc', 'url']])
    print("\n¿Qué acción te gustaría realizar?")
    print("1. Pasar al siguiente registro")
    print("2. Sustituir el valor de 'ubicacion' por el de 'ubicacion_desc'")
    print("3. Sustituir el valor manualmente")
    # Solicitar la opción al usuario
    option = input("Elige una opción (1, 2, 3): ")

    if option == '3':
        # Sustituir el valor manualmente
        new_value = input("Introduce el nuevo valor para 'ubicacion': ")
        df.at[idx, 'ubicacion'] = new_value  
    elif option == '2':
        # Sustituir el valor de 'ubicacion' por 'ubicacion_desc'
        df.at[idx, 'ubicacion'] = df.at[idx, 'ubicacion_desc']
    elif option == '1':
        # Pasar al siguiente registro
        continue
    else:
        print("Opción no válida. Pasando al siguiente registro...")
    
    print("\n---\n")

print("Proceso completado.")

# %% [markdown]
# ## b) Separación

# %% [markdown]
# Se divide la ubicación por
# * Colonia
# * Municipio
# * Estado

# %%
# Siempre regresar una lista de 3 elementos
def split_location(location):
    parts = location.split(',')
    parts += [None] * (3 - len(parts))
    return parts[:3] 
df[['Colonia', 'Municipio', 'Estado']] = df['ubicacion'].apply(split_location).apply(pd.Series)

# Limpiando valores nulos
df['Colonia'] = df['Colonia'].str.strip().fillna('Sin_colonia')
df['Municipio'] = df['Municipio'].str.strip().fillna('Sin_municipio')
df['Estado'] = df['Estado'].str.strip().fillna('Sin_estado')
df[['ubicacion', 'Colonia', 'Municipio', 'Estado']]
# Out:
#                                              ubicacion  \
# 0                        Puebla Centro, Puebla, Puebla
# 1                      Plazas Amalucan, Puebla, Puebla
# 2                      Plazas Amalucan, Puebla, Puebla
# 3                      Plazas Amalucan, Puebla, Puebla
# 4     Fraccionamiento Héroes de Puebla, Puebla, Puebla
# ...                                                ...
# 4448           Residencial Camino Real, Puebla, Puebla
# 4449        Zona Comercial Angelópolis, Puebla, Puebla
# 4451                            La Paz, Puebla, Puebla
# 4452                     Arcos del Sur, Puebla, Puebla
# 4453                            La Paz, Puebla, Puebla
#
#                                Colonia Municipio  Estado
# 0                        Puebla Centro    Puebla  Puebla
# 1                      Plazas Amalucan    Puebla  Puebla
# 2                      Plazas Amalucan    Puebla  Puebla
# 3                      Plazas Amalucan    Puebla  Puebla
# 4     Fraccionamiento Héroes de Puebla    Puebla  Puebla
# ...                                ...       ...     ...
# 4448           Residencial Camino Real    Puebla  Puebla
# 4449        Zona Comercial Angelópolis    Puebla  Puebla
# 4451                            La Paz    Puebla  Puebla
# 4452                     Arcos del Sur    Puebla  Puebla
# 4453                            La Paz    Puebla  Puebla
#
# [3712 rows x 4 columns]

# %%
incompletos = df[df['Municipio'].isna() & df['Estado'].isna()]
incompletos
# Out:
# Empty DataFrame
# Columns: [precio, denominacion, propiedad, metros_total, metros_construido, tiempo_de_publicacion, tipo, estacionamientos, recamaras, banos, medio_banos, seguridad_privada, lugar, Colonia, CP, ubicacion, url, descripcion, precio_desc, precio_mxn, precio_usd, fecha_conversion, categoria, fecha_estandarizada, meses_transcurridos, meses_transcurridos_fecha, totales_desc, construidos_desc, precio_m2_terreno, precio_m2_construido, estacionamiento_desc, recamaras_desc, baños_desc, baños_completos, medios_baños, bano_total, ubicacion_desc, Municipio, Estado]
# Index: []
#
# [0 rows x 39 columns]

# %% [markdown]
# #### Separación de tipo de lugar del nombre de la colonia

# %%
# Añade las diferentes formas de identificar el tipo de lugar (etiquetas de ubicación)
tipos = ['Condominio', 'Fraccionamiento', 'Residencial', 'Colonia']
def obtener_tipo_lugar(nombre):
    for tipo in tipos:
        if tipo in nombre:
            return tipo
    return None

df['tipo_lugar'] = df['Colonia'].apply(obtener_tipo_lugar)
# Eliminar el tipo de lugar de la columna 'colonia'
df['Colonia'] = df.apply(lambda row: row['Colonia'].replace(row['tipo_lugar'], '').strip() if row['tipo_lugar'] else row['Colonia'], axis=1)
print(df[['Colonia','tipo_lugar','ubicacion']])
# Out:
#                          Colonia       tipo_lugar  \
# 0                  Puebla Centro             None
# 1                Plazas Amalucan             None
# 2                Plazas Amalucan             None
# 3                Plazas Amalucan             None
# 4               Héroes de Puebla  Fraccionamiento
# ...                          ...              ...
# 4448                 Camino Real      Residencial
# 4449  Zona Comercial Angelópolis             None
# 4451                      La Paz             None
# 4452               Arcos del Sur             None
# 4453                      La Paz             None
#
#                                              ubicacion
# 0                        Puebla Centro, Puebla, Puebla
# 1                      Plazas Amalucan, Puebla, Puebla
# 2                      Plazas Amalucan, Puebla, Puebla
# 3                      Plazas Amalucan, Puebla, Puebla
# 4     Fraccionamiento Héroes de Puebla, Puebla, Puebla
# ...                                                ...
# 4448           Residencial Camino Real, Puebla, Puebla
# 4449        Zona Comercial Angelópolis, Puebla, Puebla
# 4451                            La Paz, Puebla, Puebla
# 4452                     Arcos del Sur, Puebla, Puebla
# 4453                            La Paz, Puebla, Puebla
#
# [3712 rows x 3 columns]

# %%
import unicodedata# Función para eliminar acentos
def eliminar_acentos(texto):
    # Normaliza y elimina los acentos
    texto_normalizado = unicodedata.normalize('NFKD', texto)
    return ''.join(char for char in texto_normalizado if unicodedata.category(char) != 'Mn')
df['Colonia'] = df['Colonia'].apply(eliminar_acentos)

# %%
df.columns
# Out:
# Index(['precio', 'denominacion', 'propiedad', 'metros_total',
#        'metros_construido', 'tiempo_de_publicacion', 'tipo',
#        'estacionamientos', 'recamaras', 'banos', 'medio_banos',
#        'seguridad_privada', 'ubicacion', 'url', 'descripcion', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'precio_desc', 'precio_mxn', 'precio_usd',
#        'fecha_conversion', 'categoria', 'fecha_estandarizada',
#        'meses_transcurridos', 'meses_transcurridos_fecha', 'totales_desc',
#        'construidos_desc', 'precio_m2_terreno', 'precio_m2_construido',
#        'estacionamiento_desc', 'recamaras_desc', 'baños_desc',
#        'baños_completos', 'medios_baños', 'bano_total'],
#       dtype='object')

# %% [markdown]
# ## c) Estandarizar valores

# %% [markdown]
# #### Preparar que se deba tener el dato de 'Municipio', 'Estado'
# Asegurate de asignar el Estado o Municipio que se esperaban dentro de las variables correspondientes

# %%
df['Estado'].unique()
# Out:
# array(['Puebla', 'Sin_estado'], dtype=object)

# %%
df['Municipio'].unique()
# Out:
# array(['Puebla', 'Puebla de Zaragoza', 'San Pedro Cholula',
#        'Sin_municipio', 'San Andrés Cholula'], dtype=object)

# %%
Estado = 'Puebla'
Municipio = 'Puebla'

df['Estado'] = df['Estado'].replace({'Sin_estado': Estado}, inplace=True)
df['Municipio'] = df['Municipio'].replace({'Sin_municipio': Municipio}, inplace=True)

# %% [markdown]
# #### Este paso es opcional, por ahora no es necesario usarlo ya que se usaba para el CP, pero estos no se tienen aún.

# %%
# Convierte todos los valores a strings, maneja NaN o None como cadenas vacías
df['Colonia'] = df['Colonia'].astype(str)
# Convertir a minúsculas
df['Colonia'] = df['Colonia'].str.lower()

import unicodedata# Función para eliminar acentos
def eliminar_acentos(texto):
    # Normaliza y elimina los acentos
    texto_normalizado = unicodedata.normalize('NFKD', texto)
    return ''.join(char for char in texto_normalizado if unicodedata.category(char) != 'Mn')
df['Colonia'] = df['Colonia'].apply(eliminar_acentos)

# Reemplazar Ñ
#df['propiedad'] = df['propiedad'].str.replace('ñ', 'n')
df['Colonia'] = df['Colonia'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)
# Convertir la primera letra de cada palabra a mayúscula
#df['Colonia'] = df['Colonia'].str.title()

# %%
# Convierte todos los valores a strings, maneja NaN o None como cadenas vacías
df['Municipio'] = df['Municipio'].astype(str)
# Convertir a minúsculas
df['Municipio'] = df['Municipio'].str.lower()

import unicodedata# Función para eliminar acentos
def eliminar_acentos(texto):
    # Normaliza y elimina los acentos
    texto_normalizado = unicodedata.normalize('NFKD', texto)
    return ''.join(char for char in texto_normalizado if unicodedata.category(char) != 'Mn')
df['Municipio'] = df['Municipio'].apply(eliminar_acentos)

# Reemplazar Ñ
#df['propiedad'] = df['propiedad'].str.replace('ñ', 'n')
df['Municipio'] = df['Municipio'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)
# Convertir la primera letra de cada palabra a mayúscula
#df['Colonia'] = df['Colonia'].str.title()

# %% [markdown]
# ## d) Mapeo de CP y tipo de lugar por diccionario

# %% [markdown]
# #### Separación de tipo de lugar del nombre de la colonia
# **PASO QUE NO SE TIENE COMPLETO**

# %%
# Cargar todas las hojas del archivo Excel en un diccionario de DataFrames
#ruta_excel = 'cp_dictionary_estandarizado.xlsx'
ruta_excel = "../cp_dictionary_estandarizado.xlsx"
hojas = pd.read_excel(ruta_excel, sheet_name=None)

# Obtener combinaciones únicas de Estado, Municipio y Colonia
combinaciones_unicas = df[['Estado', 'Municipio', 'Colonia']].drop_duplicates()

# Crear un diccionario para almacenar los códigos postales y tipos de asentamiento encontrados
codigos_postales = {}
tipos_asentamiento = {}

# Función para limpiar texto (minúsculas y sin acentos)
def limpiar_texto(texto):
    texto = texto.lower().strip()
    texto = ''.join(c for c in unicodedata.normalize('NFD', texto) if unicodedata.category(c) != 'Mn')
    return texto

# Buscar el código postal y tipo de asentamiento para cada combinación única
for _, row in combinaciones_unicas.iterrows():
    estado = limpiar_texto(row['Estado'])
    municipio = limpiar_texto(row['Municipio'])
    colonia = limpiar_texto(row['Colonia'])

    # Verificar si el estado existe en las hojas del Excel
    if estado in hojas:
        df_estado = hojas[estado]

        # Filtrar por municipio y colonia
        df_filtrado = df_estado[
            (df_estado['D_mnpio'].apply(limpiar_texto) == municipio) & 
            (df_estado['d_asenta'].apply(limpiar_texto) == colonia)
        ]

        # Si hay coincidencias, almacenar el primer código postal y tipo de asentamiento en los diccionarios
        if not df_filtrado.empty:
            codigos_postales[(estado, municipio, colonia)] = df_filtrado['d_codigo'].iloc[0]
            tipos_asentamiento[(estado, municipio, colonia)] = df_filtrado['d_tipo_asenta'].iloc[0]
        else:
            codigos_postales[(estado, municipio, colonia)] = None
            tipos_asentamiento[(estado, municipio, colonia)] = None
    else:
        codigos_postales[(estado, municipio, colonia)] = None
        tipos_asentamiento[(estado, municipio, colonia)] = None

# Crear columnas 'CP' y 'Tipo_Asentamiento' en el DataFrame original usando los diccionarios
df['CP'] = df.apply(lambda x: codigos_postales.get(
    (limpiar_texto(x['Estado']), limpiar_texto(x['Municipio']), limpiar_texto(x['Colonia']))), axis=1)
df['Tipo_Asentamiento'] = df.apply(lambda x: tipos_asentamiento.get(
    (limpiar_texto(x['Estado']), limpiar_texto(x['Municipio']), limpiar_texto(x['Colonia']))), axis=1)

# Obtener las combinaciones únicas de las columnas 'Colonia', 'Municipio', 'Estado', 'CP', 'Tipo_Asentamiento'
combinaciones_unicas = df[['Colonia', 'Municipio', 'Estado', 'CP', 'Tipo_Asentamiento']].drop_duplicates()

# Mostrar resultados
for idx, row in combinaciones_unicas.iterrows():
    print(f"Combinación {idx + 1}:")
    print(f"Colonia: {row['Colonia']}, Municipio: {row['Municipio']}, Estado: {row['Estado']}, CP: {row['CP']}, Tipo_Asentamiento: {row['Tipo_Asentamiento']}")
    print("---")

# %% [markdown]
# ____
# # 11. Variables oficiales

# %%
df = df.drop(['denominacion', 'precio_desc','baños_desc','baños_completos','medios_baños',], axis=1, errors='ignore') #'fecha_conversion'

# %%
# Tiempo de publicación limpio:
df['tiempo_de_publicacion'] = df['fecha_estandarizada']

# %% [markdown]
# EXTRA

# %%
df['Status'] = 'Venta'
df['id'] = range(1, len(df) + 1)

# %% [markdown]
# ORDEN OFICIAL

# %%
columnas_ordenadas = ['id', 'categoria', 'precio','precio_mxn','precio_usd','fecha_conversion', 'propiedad', 'metros_total', 'metros_construido',
                      'precio_m2_terreno', 'precio_m2_construido','tiempo_de_publicacion', 'meses_transcurridos','meses_transcurridos_fecha', 'tipo','Status',
                      'estacionamientos', 'recamaras', 'banos', 'medio_banos', 'bano_total','seguridad_privada', 'tipo_lugar','Colonia','Municipio','Estado','CP','ubicacion','url','descripcion']
df = df[columnas_ordenadas]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8580\391240544.py in <cell line: 4>()
#       2                       'precio_m2_terreno', 'precio_m2_construido','tiempo_de_publicacion', 'meses_transcurridos','meses_transcurridos_fecha', 'tipo','Status',
#       3                       'estacionamientos', 'recamaras', 'banos', 'medio_banos', 'bano_total','seguridad_privada', 'tipo_lugar','Colonia','Municipio','Estado','CP','ubicacion','url','descripcion']
# ----> 4 df = df[columnas_ordenadas]
#
# c:\Users\yoe11\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# c:\Users\yoe11\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# c:\Users\yoe11\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133             raise KeyError(f"{not_found} not in index")
#    6134
#    6135     @overload
#
# KeyError: "['Status', 'tipo_lugar', 'Municipio'] not in index"

# %%
columnas_ordenadas = ['id', 'categoria', 'precio','propiedad', 'metros_total', 'metros_construido',
       'precio_m2_terreno', 'precio_m2_construido',
       'meses_transcurridos', 'tipo', 'Estado',
       'estacionamientos', 'recamaras', 'banos', 'medio_banos', 'bano_total',
       'seguridad_privada', 'Colonia', 'CP',  'url', ]
df = df[columnas_ordenadas]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    132 non-null    int64
#  1   categoria             122 non-null    object
#  2   precio                132 non-null    int64
#  3   propiedad             132 non-null    object
#  4   metros_total          132 non-null    int64
#  5   metros_construido     132 non-null    int64
#  6   precio_m2_terreno     132 non-null    float64
#  7   precio_m2_construido  132 non-null    float64
#  8   meses_transcurridos   132 non-null    int64
#  9   tipo                  132 non-null    object
#  10  Estado                132 non-null    object
#  11  estacionamientos      132 non-null    int64
#  12  recamaras             132 non-null    int64
#  13  banos                 132 non-null    int64
#  14  medio_banos           132 non-null    int64
#  15  bano_total            132 non-null    float64
#  16  seguridad_privada     132 non-null    object
#  17  Colonia               132 non-null    object
#  18  CP                    132 non-null    int64
#  19  url                   132 non-null    object
# dtypes: float64(3), int64(10), object(7)
# memory usage: 20.8+ KB

# %% [markdown]
# # 13. Exportar

# %% [markdown]
# Cambia el nombre por el que desees en 'archivo'

# %%
df.isna().sum()
# Out:
# id                            0
# categoria                    10
# precio                        0
# precio_mxn                    0
# precio_usd                    0
# fecha_conversion              0
# propiedad                     0
# metros_total                  0
# metros_construido             0
# precio_m2_terreno             0
# precio_m2_construido          0
# tiempo_de_publicacion         0
# meses_transcurridos           0
# meses_transcurridos_fecha     0
# tipo                          0
# Estado                        0
# estacionamientos              0
# recamaras                     0
# banos                         0
# medio_banos                   0
# bano_total                    0
# seguridad_privada             0
# Colonia                       0
# CP                            0
# ubicacion                     0
# url                           0
# descripcion                   0
# fecha_estandarizada           0
# dtype: int64

# %%
df['categoria'].fillna('', inplace=True)

# %%
import os

archivo = 'abrill_2024'  # Nombre de archivo a exportar
ext = '.csv'  # Extensión del archivo
ciudad = 'tulancingo'  # Nombre de la ciudad en minúscula

ruta = os.path.join('..', 'ciudades', ciudad, 'clean')
if not os.path.exists(ruta):
    os.makedirs(ruta)

archivo_export = os.path.join(ruta, archivo + ext)

# Exportar el DataFrame a la ruta y archivo creados
df.to_csv(archivo_export, encoding='utf-8', index=False)
print(f"Archivo guardado en: {archivo_export}")
# Out:
# Archivo guardado en: ..\ciudades\tulancingo\clean\abrill_2024.csv

# %%
import os

archivo = 'nombre_del_archivo'  # Nombre de archivo a exportar
ext = '.csv'  # Extensión del archivo
ciudad = ''  # Nombre de la ciudad en minúscula

ruta = os.path.join('..', 'ciudades', ciudad, 'clean')
if not os.path.exists(ruta):
    os.makedirs(ruta)

archivo_export = os.path.join(ruta, archivo + ext)

# Exportar el DataFrame a la ruta y archivo creados
df.to_csv(archivo_export, encoding='utf-8', index=False)
print(f"Archivo guardado en: {archivo_export}")
# Out:
# Archivo guardado en: ..\ciudades\puebla\clean\agosto_2024.csv

# %%
archivo = 'nombre_del_archivo' # Nombre de archivo a exportar
ext = '.csv' # Extención del archivo
ciudad = '' # Nombre de la ciudad en minúscula

arch_export = archivo + ext
ruta = '../ciudades' + ciudad +'clean'
archivo_export = ciudad + arch_export
df.to_csv(archivo_export, encoding='utf-8', index=False)
